# %% [markdown]
# # CS5560 Knowledge Discovery Management
#
# # 1- Generate the following NLP tasks for the following sentence manually
# ## Input:
# - The dog saw John in the park.
# - The little bear saw the fine fat trout in the rocky brook.

# %%
t1 = "The dog saw John in the park"
t2 = "The little bear saw the fine fat trout in the rocky brook"
t3 = "Michael reads books, he loves reading them"

# %% [markdown]
# # NLP Tasks:

# %% [markdown]
# ### Installing the libraries

# %%
import nltk
from nltk import wordpunct_tokenize, pos_tag, ne_chunk
from nltk.stem import PorterStemmer, LancasterStemmer, SnowballStemmer

# %%
tt1 = nltk.word_tokenize(t1)

# %%
tt2 = nltk.word_tokenize(t2)

# %%
print("Text 1:", tt1)
print("Text 2:", tt2)
# Out:
# Text 1: ['The', 'dog', 'saw', 'John', 'in', 'the', 'park']
# Text 2: ['The', 'little', 'bear', 'saw', 'the', 'fine', 'fat', 'trout', 'in', 'the', 'rocky', 'brook']

# %% [markdown]
# ### a. Part-of-speech(POS) tagger

# %%
ta1 = nltk.pos_tag(tt1)

# %%
ta2 = nltk.pos_tag(tt2)

# %%
print("Text 1:", ta1)
print("Text 2:", ta2)
# Out:
# Text 1: [('The', 'DT'), ('dog', 'NN'), ('saw', 'VBD'), ('John', 'NNP'), ('in', 'IN'), ('the', 'DT'), ('park', 'NN')]
# Text 2: [('The', 'DT'), ('little', 'JJ'), ('bear', 'NN'), ('saw', 'VBD'), ('the', 'DT'), ('fine', 'JJ'), ('fat', 'NN'), ('trout', 'NN'), ('in', 'IN'), ('the', 'DT'), ('rocky', 'JJ'), ('brook', 'NN')]

# %% [markdown]
# ### b. Named entity recognizer (NER)

# %%
namedEnt1 = nltk.ne_chunk(ta1)
namedEnt1.draw()

# %%
namedEnt2 = nltk.ne_chunk(ta2)
print(namedEnt2)
# Out:
# (S
#   The/DT
#   little/JJ
#   bear/NN
#   saw/VBD
#   the/DT
#   fine/JJ
#   fat/NN
#   trout/NN
#   in/IN
#   the/DT
#   rocky/JJ
#   brook/NN)

# %% [markdown]
# ### c.Co-reference resolution system

# %%
# Load your usual SpaCy model (one of SpaCy English models)
import spacy
nlp = spacy.load('en')

# load NeuralCoref and add it to the pipe of SpaCy's model
import neuralcoref
coref = neuralcoref.NeuralCoref(nlp.vocab)
nlp.add_pipe(coref, name='neuralcoref')

# You're done. You can now use NeuralCoref the same way you usually manipulate a SpaCy document and it's annotations.
doc = nlp(t3)

doc._.has_coref
doc._.coref_clusters

# %% [markdown]
# # 2- Create an NLP project for the following tasks using CoreNLP
# ## Input:
# - Choose Dataset from the web (a text file)

# %% [markdown]
# ### Installing the libraries

# %%
from stanfordcorenlp import StanfordCoreNLP
import json

# %% [markdown]
# ### Connecting with the API and Loading the file

# %%
host = 'http://localhost'
port = 9000
nlp = StanfordCoreNLP(host, port=port, timeout=30000)

s = open('C:/Users/Michael/Desktop/a.txt', 'r')
# # print(s.read())
text = s.read()
# text = text.lower().split()

# %% [markdown]
# ### a. Part-of-speech(POS) tagger

# %%
p = nlp.pos_tag(text)
print('POS:', p)
# Out:
# POS: [('She', 'PRP'), ('was', 'VBD'), ('walking', 'VBG'), ('lazily', 'RB'), (',', ','), ('for', 'IN'), ('the', 'DT'), ('fierce', 'JJ'), ('April', 'NNP'), ('sun', 'NN'), ('was', 'VBD'), ('directly', 'RB'), ('overhead', 'JJ'), ('.', '.'), ('Her', 'PRP$'), ('umbrella', 'NN'), ('blocked', 'VBD'), ('its', 'PRP$'), ('rays', 'NNS'), ('but', 'CC'), ('nothing', 'NN'), ('blocked', 'VBD'), ('the', 'DT'), ('heat', 'NN'), ('-', ':'), ('the', 'DT'), ('sort', 'NN'), ('of', 'IN'), ('raw', 'JJ'), (',', ','), ('wild', 'JJ'), ('heat', 'NN'), ('that', 'WDT'), ('crushes', 'VBZ'), ('you', 'PRP'), ('with', 'IN'), ('its', 'PRP$'), ('energy', 'NN'), ('.', '.'), ('A', 'DT'), ('few', 'JJ'), ('buffalo', 'NN'), ('were', 'VBD'), ('tethered', 'JJ'), ('under', 'IN'), ('coconuts', 'NNS'), (',', ','), ('browsing', 'VBG'), ('the', 'DT'), ('parched', 'JJ'), ('verges', 'NNS'), ('.', '.'), ('Occasionally', 'RB'), ('a', 'DT'), ('car', 'NN'), ('went', 'VBD'), ('past', 'RB'), (',', ','), ('leaving', 'VBG'), ('its', 'PRP$'), ('treads', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('melting', 'NN'), ('pitch', 'NN'), ('like', 'IN'), ('the', 'DT'), ('wake', 'NN'), ('of', 'IN'), ('a', 'DT'), ('ship', 'NN'), ('at', 'IN'), ('sea', 'NN'), ('.', '.'), ('Otherwise', 'RB'), ('it', 'PRP'), ('was', 'VBD'), ('quiet', 'JJ'), (',', ','), ('and', 'CC'), ('she', 'PRP'), ('saw', 'VBD'), ('no-one', 'NN'), ('.', '.'), ('In', 'IN'), ('her', 'PRP$'), ('long', 'JJ'), ('white', 'JJ'), ('Sunday', 'NNP'), ('dress', 'NN'), ('you', 'PRP'), ('might', 'MD'), ('have', 'VB'), ('taken', 'VBN'), ('Ginnie', 'NNP'), ('Narine', 'NNP'), ('for', 'IN'), ('fourteen', 'CD'), ('or', 'CC'), ('fifteen', 'CD'), ('.', '.'), ('In', 'IN'), ('fact', 'NN'), ('she', 'PRP'), ('was', 'VBD'), ('twelve', 'CD'), (',', ','), ('a', 'DT'), ('happy', 'JJ'), (',', ','), ('uncomplicated', 'JJ'), ('child', 'NN'), ('with', 'IN'), ('a', 'DT'), ('nature', 'NN'), ('as', 'IN'), ('open', 'JJ'), ('as', 'IN'), ('the', 'DT'), ('red', 'JJ'), ('hibiscus', 'NN'), ('that', 'WDT'), ('decorated', 'VBD'), ('her', 'PRP'), ('black', 'JJ'), (',', ','), ('waist-length', 'JJ'), ('hair', 'NN'), ('.', '.'), ('Generations', 'NNS'), ('earlier', 'RBR'), ('her', 'PRP$'), ('family', 'NN'), ('had', 'VBD'), ('come', 'VBN'), ('to', 'TO'), ('Trinidad', 'NNP'), ('from', 'IN'), ('India', 'NNP'), ('as', 'IN'), ('overseers', 'NNS'), ('on', 'IN'), ('the', 'DT'), ('sugar', 'NN'), ('plantations', 'NNS'), ('.', '.'), ('Her', 'PRP$'), ('father', 'NN'), ('had', 'VBD'), ('had', 'VBN'), ('some', 'DT'), ('success', 'NN'), ('through', 'IN'), ('buying', 'NN'), ('and', 'CC'), ('clearing', 'NN'), ('land', 'NN'), ('around', 'IN'), ('Rio', 'NNP'), ('Cristalino', 'NNP'), ('and', 'CC'), ('planting', 'VBG'), ('it', 'PRP'), ('with', 'IN'), ('coffee', 'NN'), ('.', '.')]

# %% [markdown]
# ### b. Named entity recognizer (NER)

# %%
t = nlp.ner(text)
print('Tokenize:', t)
# Out:
# Tokenize: [('She', 'O'), ('was', 'O'), ('walking', 'O'), ('lazily', 'O'), (',', 'O'), ('for', 'O'), ('the', 'O'), ('fierce', 'O'), ('April', 'DATE'), ('sun', 'DATE'), ('was', 'O'), ('directly', 'O'), ('overhead', 'O'), ('.', 'O'), ('Her', 'O'), ('umbrella', 'O'), ('blocked', 'O'), ('its', 'O'), ('rays', 'O'), ('but', 'O'), ('nothing', 'O'), ('blocked', 'O'), ('the', 'O'), ('heat', 'O'), ('-', 'O'), ('the', 'O'), ('sort', 'O'), ('of', 'O'), ('raw', 'O'), (',', 'O'), ('wild', 'O'), ('heat', 'O'), ('that', 'O'), ('crushes', 'O'), ('you', 'O'), ('with', 'O'), ('its', 'O'), ('energy', 'O'), ('.', 'O'), ('A', 'O'), ('few', 'O'), ('buffalo', 'O'), ('were', 'O'), ('tethered', 'O'), ('under', 'O'), ('coconuts', 'O'), (',', 'O'), ('browsing', 'O'), ('the', 'O'), ('parched', 'O'), ('verges', 'O'), ('.', 'O'), ('Occasionally', 'O'), ('a', 'O'), ('car', 'O'), ('went', 'O'), ('past', 'DATE'), (',', 'O'), ('leaving', 'O'), ('its', 'O'), ('treads', 'O'), ('in', 'O'), ('the', 'O'), ('melting', 'O'), ('pitch', 'O'), ('like', 'O'), ('the', 'O'), ('wake', 'O'), ('of', 'O'), ('a', 'O'), ('ship', 'O'), ('at', 'O'), ('sea', 'O'), ('.', 'O'), ('Otherwise', 'O'), ('it', 'O'), ('was', 'O'), ('quiet', 'O'), (',', 'O'), ('and', 'O'), ('she', 'O'), ('saw', 'O'), ('no-one', 'O'), ('.', 'O'), ('In', 'O'), ('her', 'O'), ('long', 'O'), ('white', 'O'), ('Sunday', 'DATE'), ('dress', 'O'), ('you', 'O'), ('might', 'O'), ('have', 'O'), ('taken', 'O'), ('Ginnie', 'PERSON'), ('Narine', 'PERSON'), ('for', 'O'), ('fourteen', 'NUMBER'), ('or', 'O'), ('fifteen', 'NUMBER'), ('.', 'O'), ('In', 'O'), ('fact', 'O'), ('she', 'O'), ('was', 'O'), ('twelve', 'NUMBER'), (',', 'O'), ('a', 'O'), ('happy', 'O'), (',', 'O'), ('uncomplicated', 'O'), ('child', 'O'), ('with', 'O'), ('a', 'O'), ('nature', 'O'), ('as', 'O'), ('open', 'O'), ('as', 'O'), ('the', 'O'), ('red', 'O'), ('hibiscus', 'O'), ('that', 'O'), ('decorated', 'O'), ('her', 'O'), ('black', 'O'), (',', 'O'), ('waist-length', 'O'), ('hair', 'O'), ('.', 'O'), ('Generations', 'O'), ('earlier', 'O'), ('her', 'O'), ('family', 'O'), ('had', 'O'), ('come', 'O'), ('to', 'O'), ('Trinidad', 'CITY'), ('from', 'O'), ('India', 'COUNTRY'), ('as', 'O'), ('overseers', 'O'), ('on', 'O'), ('the', 'O'), ('sugar', 'O'), ('plantations', 'O'), ('.', 'O'), ('Her', 'O'), ('father', 'O'), ('had', 'O'), ('had', 'O'), ('some', 'O'), ('success', 'O'), ('through', 'O'), ('buying', 'O'), ('and', 'O'), ('clearing', 'O'), ('land', 'O'), ('around', 'O'), ('Rio', 'LOCATION'), ('Cristalino', 'LOCATION'), ('and', 'O'), ('planting', 'O'), ('it', 'O'), ('with', 'O'), ('coffee', 'O'), ('.', 'O')]

# %% [markdown]
# ### c. Co-reference resolution system

# %%
res1 = nlp.annotate(text,
                   properties={
                       'annotators': 'coref',
                       'pinelineLanguage':'en',
                       'timeout': 30000,
                   })

# %%
print(res1)
# Out:
# {
#   "sentences": [
#     {
#       "index": 0,
#       "basicDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 13,
#           "dependentGloss": "overhead"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 1,
#           "dependentGloss": "She"
#         },
#         {
#           "dep": "aux",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 2,
#           "dependentGloss": "was"
#         },
#         {
#           "dep": "csubj",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 3,
#           "dependentGloss": "walking"
#         },
#         {
#           "dep": "advmod",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 4,
#           "dependentGloss": "lazily"
#         },
#         {
#           "dep": "punct",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 5,
#           "dependentGloss": ","
#         },
#         {
#           "dep": "case",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 6,
#           "dependentGloss": "for"
#         },
#         {
#           "dep": "det",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 7,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "amod",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 8,
#           "dependentGloss": "fierce"
#         },
#         {
#           "dep": "compound",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 9,
#           "dependentGloss": "April"
#         },
#         {
#           "dep": "nmod",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 10,
#           "dependentGloss": "sun"
#         },
#         {
#           "dep": "cop",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 11,
#           "dependentGloss": "was"
#         },
#         {
#           "dep": "advmod",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 12,
#           "dependentGloss": "directly"
#         },
#         {
#           "dep": "punct",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 14,
#           "dependentGloss": "."
#         }
#       ],
#       "enhancedDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 13,
#           "dependentGloss": "overhead"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 1,
#           "dependentGloss": "She"
#         },
#         {
#           "dep": "aux",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 2,
#           "dependentGloss": "was"
#         },
#         {
#           "dep": "csubj",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 3,
#           "dependentGloss": "walking"
#         },
#         {
#           "dep": "advmod",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 4,
#           "dependentGloss": "lazily"
#         },
#         {
#           "dep": "punct",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 5,
#           "dependentGloss": ","
#         },
#         {
#           "dep": "case",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 6,
#           "dependentGloss": "for"
#         },
#         {
#           "dep": "det",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 7,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "amod",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 8,
#           "dependentGloss": "fierce"
#         },
#         {
#           "dep": "compound",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 9,
#           "dependentGloss": "April"
#         },
#         {
#           "dep": "nmod:for",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 10,
#           "dependentGloss": "sun"
#         },
#         {
#           "dep": "cop",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 11,
#           "dependentGloss": "was"
#         },
#         {
#           "dep": "advmod",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 12,
#           "dependentGloss": "directly"
#         },
#         {
#           "dep": "punct",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 14,
#           "dependentGloss": "."
#         }
#       ],
#       "enhancedPlusPlusDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 13,
#           "dependentGloss": "overhead"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 1,
#           "dependentGloss": "She"
#         },
#         {
#           "dep": "aux",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 2,
#           "dependentGloss": "was"
#         },
#         {
#           "dep": "csubj",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 3,
#           "dependentGloss": "walking"
#         },
#         {
#           "dep": "advmod",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 4,
#           "dependentGloss": "lazily"
#         },
#         {
#           "dep": "punct",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 5,
#           "dependentGloss": ","
#         },
#         {
#           "dep": "case",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 6,
#           "dependentGloss": "for"
#         },
#         {
#           "dep": "det",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 7,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "amod",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 8,
#           "dependentGloss": "fierce"
#         },
#         {
#           "dep": "compound",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 9,
#           "dependentGloss": "April"
#         },
#         {
#           "dep": "nmod:for",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 10,
#           "dependentGloss": "sun"
#         },
#         {
#           "dep": "cop",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 11,
#           "dependentGloss": "was"
#         },
#         {
#           "dep": "advmod",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 12,
#           "dependentGloss": "directly"
#         },
#         {
#           "dep": "punct",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 14,
#           "dependentGloss": "."
#         }
#       ],
#       "entitymentions": [
#         {
#           "docTokenBegin": 8,
#           "docTokenEnd": 10,
#           "tokenBegin": 8,
#           "tokenEnd": 10,
#           "text": "April sun",
#           "characterOffsetBegin": 39,
#           "characterOffsetEnd": 48,
#           "ner": "DATE",
#           "normalizedNER": "XXXX-WXX-7",
#           "timex": {
#             "tid": "t1",
#             "type": "DATE",
#             "value": "XXXX-WXX-7"
#           }
#         },
#         {
#           "docTokenBegin": 0,
#           "docTokenEnd": 1,
#           "tokenBegin": 0,
#           "tokenEnd": 1,
#           "text": "She",
#           "characterOffsetBegin": 0,
#           "characterOffsetEnd": 3,
#           "ner": "PERSON"
#         }
#       ],
#       "tokens": [
#         {
#           "index": 1,
#           "word": "She",
#           "originalText": "She",
#           "lemma": "she",
#           "characterOffsetBegin": 0,
#           "characterOffsetEnd": 3,
#           "pos": "PRP",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": "",
#           "after": " "
#         },
#         {
#           "index": 2,
#           "word": "was",
#           "originalText": "was",
#           "lemma": "be",
#           "characterOffsetBegin": 4,
#           "characterOffsetEnd": 7,
#           "pos": "VBD",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 3,
#           "word": "walking",
#           "originalText": "walking",
#           "lemma": "walk",
#           "characterOffsetBegin": 8,
#           "characterOffsetEnd": 15,
#           "pos": "VBG",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 4,
#           "word": "lazily",
#           "originalText": "lazily",
#           "lemma": "lazily",
#           "characterOffsetBegin": 16,
#           "characterOffsetEnd": 22,
#           "pos": "RB",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": ""
#         },
#         {
#           "index": 5,
#           "word": ",",
#           "originalText": ",",
#           "lemma": ",",
#           "characterOffsetBegin": 22,
#           "characterOffsetEnd": 23,
#           "pos": ",",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": "",
#           "after": " "
#         },
#         {
#           "index": 6,
#           "word": "for",
#           "originalText": "for",
#           "lemma": "for",
#           "characterOffsetBegin": 24,
#           "characterOffsetEnd": 27,
#           "pos": "IN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 7,
#           "word": "the",
#           "originalText": "the",
#           "lemma": "the",
#           "characterOffsetBegin": 28,
#           "characterOffsetEnd": 31,
#           "pos": "DT",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 8,
#           "word": "fierce",
#           "originalText": "fierce",
#           "lemma": "fierce",
#           "characterOffsetBegin": 32,
#           "characterOffsetEnd": 38,
#           "pos": "JJ",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 9,
#           "word": "April",
#           "originalText": "April",
#           "lemma": "April",
#           "characterOffsetBegin": 39,
#           "characterOffsetEnd": 44,
#           "pos": "NNP",
#           "ner": "DATE",
#           "normalizedNER": "XXXX-WXX-7",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " ",
#           "timex": {
#             "tid": "t1",
#             "type": "DATE",
#             "value": "XXXX-WXX-7"
#           }
#         },
#         {
#           "index": 10,
#           "word": "sun",
#           "originalText": "sun",
#           "lemma": "sun",
#           "characterOffsetBegin": 45,
#           "characterOffsetEnd": 48,
#           "pos": "NN",
#           "ner": "DATE",
#           "normalizedNER": "XXXX-WXX-7",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " ",
#           "timex": {
#             "tid": "t1",
#             "type": "DATE",
#             "value": "XXXX-WXX-7"
#           }
#         },
#         {
#           "index": 11,
#           "word": "was",
#           "originalText": "was",
#           "lemma": "be",
#           "characterOffsetBegin": 49,
#           "characterOffsetEnd": 52,
#           "pos": "VBD",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 12,
#           "word": "directly",
#           "originalText": "directly",
#           "lemma": "directly",
#           "characterOffsetBegin": 53,
#           "characterOffsetEnd": 61,
#           "pos": "RB",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 13,
#           "word": "overhead",
#           "originalText": "overhead",
#           "lemma": "overhead",
#           "characterOffsetBegin": 62,
#           "characterOffsetEnd": 70,
#           "pos": "JJ",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": ""
#         },
#         {
#           "index": 14,
#           "word": ".",
#           "originalText": ".",
#           "lemma": ".",
#           "characterOffsetBegin": 70,
#           "characterOffsetEnd": 71,
#           "pos": ".",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": "",
#           "after": " "
#         }
#       ]
#     },
#     {
#       "index": 1,
#       "basicDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 3,
#           "dependentGloss": "blocked"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 2,
#           "governorGloss": "umbrella",
#           "dependent": 1,
#           "dependentGloss": "Her"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 2,
#           "dependentGloss": "umbrella"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 5,
#           "governorGloss": "rays",
#           "dependent": 4,
#           "dependentGloss": "its"
#         },
#         {
#           "dep": "dobj",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 5,
#           "dependentGloss": "rays"
#         },
#         {
#           "dep": "cc",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 6,
#           "dependentGloss": "but"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 8,
#           "governorGloss": "blocked",
#           "dependent": 7,
#           "dependentGloss": "nothing"
#         },
#         {
#           "dep": "conj",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 8,
#           "dependentGloss": "blocked"
#         },
#         {
#           "dep": "det",
#           "governor": 10,
#           "governorGloss": "heat",
#           "dependent": 9,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "dobj",
#           "governor": 8,
#           "governorGloss": "blocked",
#           "dependent": 10,
#           "dependentGloss": "heat"
#         },
#         {
#           "dep": "punct",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 11,
#           "dependentGloss": "-"
#         },
#         {
#           "dep": "det",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 12,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "dobj",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 13,
#           "dependentGloss": "sort"
#         },
#         {
#           "dep": "case",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 14,
#           "dependentGloss": "of"
#         },
#         {
#           "dep": "amod",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 15,
#           "dependentGloss": "raw"
#         },
#         {
#           "dep": "punct",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 16,
#           "dependentGloss": ","
#         },
#         {
#           "dep": "amod",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 17,
#           "dependentGloss": "wild"
#         },
#         {
#           "dep": "nmod",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 18,
#           "dependentGloss": "heat"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 20,
#           "governorGloss": "crushes",
#           "dependent": 19,
#           "dependentGloss": "that"
#         },
#         {
#           "dep": "acl:relcl",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 20,
#           "dependentGloss": "crushes"
#         },
#         {
#           "dep": "dobj",
#           "governor": 20,
#           "governorGloss": "crushes",
#           "dependent": 21,
#           "dependentGloss": "you"
#         },
#         {
#           "dep": "case",
#           "governor": 24,
#           "governorGloss": "energy",
#           "dependent": 22,
#           "dependentGloss": "with"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 24,
#           "governorGloss": "energy",
#           "dependent": 23,
#           "dependentGloss": "its"
#         },
#         {
#           "dep": "nmod",
#           "governor": 20,
#           "governorGloss": "crushes",
#           "dependent": 24,
#           "dependentGloss": "energy"
#         },
#         {
#           "dep": "punct",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 25,
#           "dependentGloss": "."
#         }
#       ],
#       "enhancedDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 3,
#           "dependentGloss": "blocked"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 2,
#           "governorGloss": "umbrella",
#           "dependent": 1,
#           "dependentGloss": "Her"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 2,
#           "dependentGloss": "umbrella"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 5,
#           "governorGloss": "rays",
#           "dependent": 4,
#           "dependentGloss": "its"
#         },
#         {
#           "dep": "dobj",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 5,
#           "dependentGloss": "rays"
#         },
#         {
#           "dep": "cc",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 6,
#           "dependentGloss": "but"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 8,
#           "governorGloss": "blocked",
#           "dependent": 7,
#           "dependentGloss": "nothing"
#         },
#         {
#           "dep": "conj:but",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 8,
#           "dependentGloss": "blocked"
#         },
#         {
#           "dep": "det",
#           "governor": 10,
#           "governorGloss": "heat",
#           "dependent": 9,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "dobj",
#           "governor": 8,
#           "governorGloss": "blocked",
#           "dependent": 10,
#           "dependentGloss": "heat"
#         },
#         {
#           "dep": "punct",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 11,
#           "dependentGloss": "-"
#         },
#         {
#           "dep": "det",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 12,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "dobj",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 13,
#           "dependentGloss": "sort"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 20,
#           "governorGloss": "crushes",
#           "dependent": 13,
#           "dependentGloss": "sort"
#         },
#         {
#           "dep": "case",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 14,
#           "dependentGloss": "of"
#         },
#         {
#           "dep": "amod",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 15,
#           "dependentGloss": "raw"
#         },
#         {
#           "dep": "punct",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 16,
#           "dependentGloss": ","
#         },
#         {
#           "dep": "amod",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 17,
#           "dependentGloss": "wild"
#         },
#         {
#           "dep": "nmod:of",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 18,
#           "dependentGloss": "heat"
#         },
#         {
#           "dep": "ref",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 19,
#           "dependentGloss": "that"
#         },
#         {
#           "dep": "acl:relcl",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 20,
#           "dependentGloss": "crushes"
#         },
#         {
#           "dep": "dobj",
#           "governor": 20,
#           "governorGloss": "crushes",
#           "dependent": 21,
#           "dependentGloss": "you"
#         },
#         {
#           "dep": "case",
#           "governor": 24,
#           "governorGloss": "energy",
#           "dependent": 22,
#           "dependentGloss": "with"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 24,
#           "governorGloss": "energy",
#           "dependent": 23,
#           "dependentGloss": "its"
#         },
#         {
#           "dep": "nmod:with",
#           "governor": 20,
#           "governorGloss": "crushes",
#           "dependent": 24,
#           "dependentGloss": "energy"
#         },
#         {
#           "dep": "punct",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 25,
#           "dependentGloss": "."
#         }
#       ],
#       "enhancedPlusPlusDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 3,
#           "dependentGloss": "blocked"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 2,
#           "governorGloss": "umbrella",
#           "dependent": 1,
#           "dependentGloss": "Her"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 2,
#           "dependentGloss": "umbrella"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 5,
#           "governorGloss": "rays",
#           "dependent": 4,
#           "dependentGloss": "its"
#         },
#         {
#           "dep": "dobj",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 5,
#           "dependentGloss": "rays"
#         },
#         {
#           "dep": "cc",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 6,
#           "dependentGloss": "but"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 8,
#           "governorGloss": "blocked",
#           "dependent": 7,
#           "dependentGloss": "nothing"
#         },
#         {
#           "dep": "conj:but",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 8,
#           "dependentGloss": "blocked"
#         },
#         {
#           "dep": "det",
#           "governor": 10,
#           "governorGloss": "heat",
#           "dependent": 9,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "dobj",
#           "governor": 8,
#           "governorGloss": "blocked",
#           "dependent": 10,
#           "dependentGloss": "heat"
#         },
#         {
#           "dep": "punct",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 11,
#           "dependentGloss": "-"
#         },
#         {
#           "dep": "det",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 12,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "dobj",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 13,
#           "dependentGloss": "sort"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 20,
#           "governorGloss": "crushes",
#           "dependent": 13,
#           "dependentGloss": "sort"
#         },
#         {
#           "dep": "case",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 14,
#           "dependentGloss": "of"
#         },
#         {
#           "dep": "amod",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 15,
#           "dependentGloss": "raw"
#         },
#         {
#           "dep": "punct",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 16,
#           "dependentGloss": ","
#         },
#         {
#           "dep": "amod",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 17,
#           "dependentGloss": "wild"
#         },
#         {
#           "dep": "nmod:of",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 18,
#           "dependentGloss": "heat"
#         },
#         {
#           "dep": "ref",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 19,
#           "dependentGloss": "that"
#         },
#         {
#           "dep": "acl:relcl",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 20,
#           "dependentGloss": "crushes"
#         },
#         {
#           "dep": "dobj",
#           "governor": 20,
#           "governorGloss": "crushes",
#           "dependent": 21,
#           "dependentGloss": "you"
#         },
#         {
#           "dep": "case",
#           "governor": 24,
#           "governorGloss": "energy",
#           "dependent": 22,
#           "dependentGloss": "with"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 24,
#           "governorGloss": "energy",
#           "dependent": 23,
#           "dependentGloss": "its"
#         },
#         {
#           "dep": "nmod:with",
#           "governor": 20,
#           "governorGloss": "crushes",
#           "dependent": 24,
#           "dependentGloss": "energy"
#         },
#         {
#           "dep": "punct",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 25,
#           "dependentGloss": "."
#         }
#       ],
#       "entitymentions": [
#         {
#           "docTokenBegin": 14,
#           "docTokenEnd": 15,
#           "tokenBegin": 0,
#           "tokenEnd": 1,
#           "text": "Her",
#           "characterOffsetBegin": 72,
#           "characterOffsetEnd": 75,
#           "ner": "PERSON"
#         }
#       ],
#       "tokens": [
#         {
#           "index": 1,
#           "word": "Her",
#           "originalText": "Her",
#           "lemma": "she",
#           "characterOffsetBegin": 72,
#           "characterOffsetEnd": 75,
#           "pos": "PRP$",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 2,
#           "word": "umbrella",
#           "originalText": "umbrella",
#           "lemma": "umbrella",
#           "characterOffsetBegin": 76,
#           "characterOffsetEnd": 84,
#           "pos": "NN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 3,
#           "word": "blocked",
#           "originalText": "blocked",
#           "lemma": "block",
#           "characterOffsetBegin": 85,
#           "characterOffsetEnd": 92,
#           "pos": "VBD",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 4,
#           "word": "its",
#           "originalText": "its",
#           "lemma": "its",
#           "characterOffsetBegin": 93,
#           "characterOffsetEnd": 96,
#           "pos": "PRP$",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 5,
#           "word": "rays",
#           "originalText": "rays",
#           "lemma": "ray",
#           "characterOffsetBegin": 97,
#           "characterOffsetEnd": 101,
#           "pos": "NNS",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 6,
#           "word": "but",
#           "originalText": "but",
#           "lemma": "but",
#           "characterOffsetBegin": 102,
#           "characterOffsetEnd": 105,
#           "pos": "CC",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 7,
#           "word": "nothing",
#           "originalText": "nothing",
#           "lemma": "nothing",
#           "characterOffsetBegin": 106,
#           "characterOffsetEnd": 113,
#           "pos": "NN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 8,
#           "word": "blocked",
#           "originalText": "blocked",
#           "lemma": "block",
#           "characterOffsetBegin": 114,
#           "characterOffsetEnd": 121,
#           "pos": "VBD",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 9,
#           "word": "the",
#           "originalText": "the",
#           "lemma": "the",
#           "characterOffsetBegin": 122,
#           "characterOffsetEnd": 125,
#           "pos": "DT",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 10,
#           "word": "heat",
#           "originalText": "heat",
#           "lemma": "heat",
#           "characterOffsetBegin": 126,
#           "characterOffsetEnd": 130,
#           "pos": "NN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 11,
#           "word": "-",
#           "originalText": "-",
#           "lemma": "-",
#           "characterOffsetBegin": 131,
#           "characterOffsetEnd": 132,
#           "pos": ":",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 12,
#           "word": "the",
#           "originalText": "the",
#           "lemma": "the",
#           "characterOffsetBegin": 133,
#           "characterOffsetEnd": 136,
#           "pos": "DT",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 13,
#           "word": "sort",
#           "originalText": "sort",
#           "lemma": "sort",
#           "characterOffsetBegin": 137,
#           "characterOffsetEnd": 141,
#           "pos": "NN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 14,
#           "word": "of",
#           "originalText": "of",
#           "lemma": "of",
#           "characterOffsetBegin": 142,
#           "characterOffsetEnd": 144,
#           "pos": "IN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 15,
#           "word": "raw",
#           "originalText": "raw",
#           "lemma": "raw",
#           "characterOffsetBegin": 145,
#           "characterOffsetEnd": 148,
#           "pos": "JJ",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": ""
#         },
#         {
#           "index": 16,
#           "word": ",",
#           "originalText": ",",
#           "lemma": ",",
#           "characterOffsetBegin": 148,
#           "characterOffsetEnd": 149,
#           "pos": ",",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": "",
#           "after": " "
#         },
#         {
#           "index": 17,
#           "word": "wild",
#           "originalText": "wild",
#           "lemma": "wild",
#           "characterOffsetBegin": 150,
#           "characterOffsetEnd": 154,
#           "pos": "JJ",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 18,
#           "word": "heat",
#           "originalText": "heat",
#           "lemma": "heat",
#           "characterOffsetBegin": 155,
#           "characterOffsetEnd": 159,
#           "pos": "NN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 19,
#           "word": "that",
#           "originalText": "that",
#           "lemma": "that",
#           "characterOffsetBegin": 160,
#           "characterOffsetEnd": 164,
#           "pos": "WDT",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 20,
#           "word": "crushes",
#           "originalText": "crushes",
#           "lemma": "crush",
#           "characterOffsetBegin": 165,
#           "characterOffsetEnd": 172,
#           "pos": "VBZ",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 21,
#           "word": "you",
#           "originalText": "you",
#           "lemma": "you",
#           "characterOffsetBegin": 173,
#           "characterOffsetEnd": 176,
#           "pos": "PRP",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 22,
#           "word": "with",
#           "originalText": "with",
#           "lemma": "with",
#           "characterOffsetBegin": 177,
#           "characterOffsetEnd": 181,
#           "pos": "IN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 23,
#           "word": "its",
#           "originalText": "its",
#           "lemma": "its",
#           "characterOffsetBegin": 182,
#           "characterOffsetEnd": 185,
#           "pos": "PRP$",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 24,
#           "word": "energy",
#           "originalText": "energy",
#           "lemma": "energy",
#           "characterOffsetBegin": 186,
#           "characterOffsetEnd": 192,
#           "pos": "NN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": ""
#         },
#         {
#           "index": 25,
#           "word": ".",
#           "originalText": ".",
#           "lemma": ".",
#           "characterOffsetBegin": 192,
#           "characterOffsetEnd": 193,
#           "pos": ".",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": "",
#           "after": " "
#         }
#       ]
#     },
#     {
#       "index": 2,
#       "basicDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 5,
#           "dependentGloss": "tethered"
#         },
#         {
#           "dep": "det",
#           "governor": 3,
#           "governorGloss": "buffalo",
#           "dependent": 1,
#           "dependentGloss": "A"
#         },
#         {
#           "dep": "amod",
#           "governor": 3,
#           "governorGloss": "buffalo",
#           "dependent": 2,
#           "dependentGloss": "few"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 3,
#           "dependentGloss": "buffalo"
#         },
#         {
#           "dep": "cop",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 4,
#           "dependentGloss": "were"
#         },
#         {
#           "dep": "case",
#           "governor": 7,
#           "governorGloss": "coconuts",
#           "dependent": 6,
#           "dependentGloss": "under"
#         },
#         {
#           "dep": "nmod",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 7,
#           "dependentGloss": "coconuts"
#         },
#         {
#           "dep": "punct",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 8,
#           "dependentGloss": ","
#         },
#         {
#           "dep": "xcomp",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 9,
#           "dependentGloss": "browsing"
#         },
#         {
#           "dep": "det",
#           "governor": 12,
#           "governorGloss": "verges",
#           "dependent": 10,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "amod",
#           "governor": 12,
#           "governorGloss": "verges",
#           "dependent": 11,
#           "dependentGloss": "parched"
#         },
#         {
#           "dep": "dobj",
#           "governor": 9,
#           "governorGloss": "browsing",
#           "dependent": 12,
#           "dependentGloss": "verges"
#         },
#         {
#           "dep": "punct",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 13,
#           "dependentGloss": "."
#         }
#       ],
#       "enhancedDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 5,
#           "dependentGloss": "tethered"
#         },
#         {
#           "dep": "det",
#           "governor": 3,
#           "governorGloss": "buffalo",
#           "dependent": 1,
#           "dependentGloss": "A"
#         },
#         {
#           "dep": "amod",
#           "governor": 3,
#           "governorGloss": "buffalo",
#           "dependent": 2,
#           "dependentGloss": "few"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 3,
#           "dependentGloss": "buffalo"
#         },
#         {
#           "dep": "cop",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 4,
#           "dependentGloss": "were"
#         },
#         {
#           "dep": "case",
#           "governor": 7,
#           "governorGloss": "coconuts",
#           "dependent": 6,
#           "dependentGloss": "under"
#         },
#         {
#           "dep": "nmod:under",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 7,
#           "dependentGloss": "coconuts"
#         },
#         {
#           "dep": "punct",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 8,
#           "dependentGloss": ","
#         },
#         {
#           "dep": "xcomp",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 9,
#           "dependentGloss": "browsing"
#         },
#         {
#           "dep": "det",
#           "governor": 12,
#           "governorGloss": "verges",
#           "dependent": 10,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "amod",
#           "governor": 12,
#           "governorGloss": "verges",
#           "dependent": 11,
#           "dependentGloss": "parched"
#         },
#         {
#           "dep": "dobj",
#           "governor": 9,
#           "governorGloss": "browsing",
#           "dependent": 12,
#           "dependentGloss": "verges"
#         },
#         {
#           "dep": "punct",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 13,
#           "dependentGloss": "."
#         }
#       ],
#       "enhancedPlusPlusDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 5,
#           "dependentGloss": "tethered"
#         },
#         {
#           "dep": "det",
#           "governor": 3,
#           "governorGloss": "buffalo",
#           "dependent": 1,
#           "dependentGloss": "A"
#         },
#         {
#           "dep": "amod",
#           "governor": 3,
#           "governorGloss": "buffalo",
#           "dependent": 2,
#           "dependentGloss": "few"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 3,
#           "dependentGloss": "buffalo"
#         },
#         {
#           "dep": "cop",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 4,
#           "dependentGloss": "were"
#         },
#         {
#           "dep": "case",
#           "governor": 7,
#           "governorGloss": "coconuts",
#           "dependent": 6,
#           "dependentGloss": "under"
#         },
#         {
#           "dep": "nmod:under",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 7,
#           "dependentGloss": "coconuts"
#         },
#         {
#           "dep": "punct",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 8,
#           "dependentGloss": ","
#         },
#         {
#           "dep": "xcomp",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 9,
#           "dependentGloss": "browsing"
#         },
#         {
#           "dep": "det",
#           "governor": 12,
#           "governorGloss": "verges",
#           "dependent": 10,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "amod",
#           "governor": 12,
#           "governorGloss": "verges",
#           "dependent": 11,
#           "dependentGloss": "parched"
#         },
#         {
#           "dep": "dobj",
#           "governor": 9,
#           "governorGloss": "browsing",
#           "dependent": 12,
#           "dependentGloss": "verges"
#         },
#         {
#           "dep": "punct",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 13,
#           "dependentGloss": "."
#         }
#       ],
#       "entitymentions": [
#       ],
#       "tokens": [
#         {
#           "index": 1,
#           "word": "A",
#           "originalText": "A",
#           "lemma": "a",
#           "characterOffsetBegin": 194,
#           "characterOffsetEnd": 195,
#           "pos": "DT",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 2,
#           "word": "few",
#           "originalText": "few",
#           "lemma": "few",
#           "characterOffsetBegin": 196,
#           "characterOffsetEnd": 199,
#           "pos": "JJ",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 3,
#           "word": "buffalo",
#           "originalText": "buffalo",
#           "lemma": "buffalo",
#           "characterOffsetBegin": 200,
#           "characterOffsetEnd": 207,
#           "pos": "NN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 4,
#           "word": "were",
#           "originalText": "were",
#           "lemma": "be",
#           "characterOffsetBegin": 208,
#           "characterOffsetEnd": 212,
#           "pos": "VBD",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 5,
#           "word": "tethered",
#           "originalText": "tethered",
#           "lemma": "tethered",
#           "characterOffsetBegin": 213,
#           "characterOffsetEnd": 221,
#           "pos": "JJ",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 6,
#           "word": "under",
#           "originalText": "under",
#           "lemma": "under",
#           "characterOffsetBegin": 222,
#           "characterOffsetEnd": 227,
#           "pos": "IN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 7,
#           "word": "coconuts",
#           "originalText": "coconuts",
#           "lemma": "coconut",
#           "characterOffsetBegin": 228,
#           "characterOffsetEnd": 236,
#           "pos": "NNS",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": ""
#         },
#         {
#           "index": 8,
#           "word": ",",
#           "originalText": ",",
#           "lemma": ",",
#           "characterOffsetBegin": 236,
#           "characterOffsetEnd": 237,
#           "pos": ",",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": "",
#           "after": " "
#         },
#         {
#           "index": 9,
#           "word": "browsing",
#           "originalText": "browsing",
#           "lemma": "browse",
#           "characterOffsetBegin": 238,
#           "characterOffsetEnd": 246,
#           "pos": "VBG",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 10,
#           "word": "the",
#           "originalText": "the",
#           "lemma": "the",
#           "characterOffsetBegin": 247,
#           "characterOffsetEnd": 250,
#           "pos": "DT",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 11,
#           "word": "parched",
#           "originalText": "parched",
#           "lemma": "parched",
#           "characterOffsetBegin": 251,
#           "characterOffsetEnd": 258,
#           "pos": "JJ",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 12,
#           "word": "verges",
#           "originalText": "verges",
#           "lemma": "verge",
#           "characterOffsetBegin": 259,
#           "characterOffsetEnd": 265,
#           "pos": "NNS",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": ""
#         },
#         {
#           "index": 13,
#           "word": ".",
#           "originalText": ".",
#           "lemma": ".",
#           "characterOffsetBegin": 265,
#           "characterOffsetEnd": 266,
#           "pos": ".",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": "",
#           "after": " "
#         }
#       ]
#     },
#     {
#       "index": 3,
#       "basicDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 4,
#           "dependentGloss": "went"
#         },
#         {
#           "dep": "advmod",
#           "governor": 4,
#           "governorGloss": "went",
#           "dependent": 1,
#           "dependentGloss": "Occasionally"
#         },
#         {
#           "dep": "det",
#           "governor": 3,
#           "governorGloss": "car",
#           "dependent": 2,
#           "dependentGloss": "a"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 4,
#           "governorGloss": "went",
#           "dependent": 3,
#           "dependentGloss": "car"
#         },
#         {
#           "dep": "advmod",
#           "governor": 4,
#           "governorGloss": "went",
#           "dependent": 5,
#           "dependentGloss": "past"
#         },
#         {
#           "dep": "punct",
#           "governor": 4,
#           "governorGloss": "went",
#           "dependent": 6,
#           "dependentGloss": ","
#         },
#         {
#           "dep": "advcl",
#           "governor": 4,
#           "governorGloss": "went",
#           "dependent": 7,
#           "dependentGloss": "leaving"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 9,
#           "governorGloss": "treads",
#           "dependent": 8,
#           "dependentGloss": "its"
#         },
#         {
#           "dep": "dobj",
#           "governor": 7,
#           "governorGloss": "leaving",
#           "dependent": 9,
#           "dependentGloss": "treads"
#         },
#         {
#           "dep": "case",
#           "governor": 13,
#           "governorGloss": "pitch",
#           "dependent": 10,
#           "dependentGloss": "in"
#         },
#         {
#           "dep": "det",
#           "governor": 13,
#           "governorGloss": "pitch",
#           "dependent": 11,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "compound",
# ...
#         },
#         {
#           "dep": "case",
#           "governor": 8,
#           "governorGloss": "buying",
#           "dependent": 7,
#           "dependentGloss": "through"
#         },
#         {
#           "dep": "nmod:through",
#           "governor": 6,
#           "governorGloss": "success",
#           "dependent": 8,
#           "dependentGloss": "buying"
#         },
#         {
#           "dep": "cc",
#           "governor": 8,
#           "governorGloss": "buying",
#           "dependent": 9,
#           "dependentGloss": "and"
#         },
#         {
#           "dep": "compound",
#           "governor": 11,
#           "governorGloss": "land",
#           "dependent": 10,
#           "dependentGloss": "clearing"
#         },
#         {
#           "dep": "nmod:through",
#           "governor": 6,
#           "governorGloss": "success",
#           "dependent": 11,
#           "dependentGloss": "land"
#         },
#         {
#           "dep": "conj:and",
#           "governor": 8,
#           "governorGloss": "buying",
#           "dependent": 11,
#           "dependentGloss": "land"
#         },
#         {
#           "dep": "case",
#           "governor": 14,
#           "governorGloss": "Cristalino",
#           "dependent": 12,
#           "dependentGloss": "around"
#         },
#         {
#           "dep": "compound",
#           "governor": 14,
#           "governorGloss": "Cristalino",
#           "dependent": 13,
#           "dependentGloss": "Rio"
#         },
#         {
#           "dep": "nmod:around",
#           "governor": 8,
#           "governorGloss": "buying",
#           "dependent": 14,
#           "dependentGloss": "Cristalino"
#         },
#         {
#           "dep": "cc",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 15,
#           "dependentGloss": "and"
#         },
#         {
#           "dep": "conj:and",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 16,
#           "dependentGloss": "planting"
#         },
#         {
#           "dep": "dobj",
#           "governor": 16,
#           "governorGloss": "planting",
#           "dependent": 17,
#           "dependentGloss": "it"
#         },
#         {
#           "dep": "case",
#           "governor": 19,
#           "governorGloss": "coffee",
#           "dependent": 18,
#           "dependentGloss": "with"
#         },
#         {
#           "dep": "nmod:with",
#           "governor": 16,
#           "governorGloss": "planting",
#           "dependent": 19,
#           "dependentGloss": "coffee"
#         },
#         {
#           "dep": "punct",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 20,
#           "dependentGloss": "."
#         }
#       ],
#       "entitymentions": [
#         {
#           "docTokenBegin": 158,
#           "docTokenEnd": 160,
#           "tokenBegin": 12,
#           "tokenEnd": 14,
#           "text": "Rio Cristalino",
#           "characterOffsetBegin": 817,
#           "characterOffsetEnd": 831,
#           "ner": "LOCATION"
#         },
#         {
#           "docTokenBegin": 146,
#           "docTokenEnd": 147,
#           "tokenBegin": 0,
#           "tokenEnd": 1,
#           "text": "Her",
#           "characterOffsetBegin": 745,
#           "characterOffsetEnd": 748,
#           "ner": "PERSON"
#         }
#       ],
#       "tokens": [
#         {
#           "index": 1,
#           "word": "Her",
#           "originalText": "Her",
#           "lemma": "she",
#           "characterOffsetBegin": 745,
#           "characterOffsetEnd": 748,
#           "pos": "PRP$",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 2,
#           "word": "father",
#           "originalText": "father",
#           "lemma": "father",
#           "characterOffsetBegin": 749,
#           "characterOffsetEnd": 755,
#           "pos": "NN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 3,
#           "word": "had",
#           "originalText": "had",
#           "lemma": "have",
#           "characterOffsetBegin": 756,
#           "characterOffsetEnd": 759,
#           "pos": "VBD",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 4,
#           "word": "had",
#           "originalText": "had",
#           "lemma": "have",
#           "characterOffsetBegin": 760,
#           "characterOffsetEnd": 763,
#           "pos": "VBN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 5,
#           "word": "some",
#           "originalText": "some",
#           "lemma": "some",
#           "characterOffsetBegin": 764,
#           "characterOffsetEnd": 768,
#           "pos": "DT",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 6,
#           "word": "success",
#           "originalText": "success",
#           "lemma": "success",
#           "characterOffsetBegin": 769,
#           "characterOffsetEnd": 776,
#           "pos": "NN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 7,
#           "word": "through",
#           "originalText": "through",
#           "lemma": "through",
#           "characterOffsetBegin": 777,
#           "characterOffsetEnd": 784,
#           "pos": "IN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 8,
#           "word": "buying",
#           "originalText": "buying",
#           "lemma": "buying",
#           "characterOffsetBegin": 785,
#           "characterOffsetEnd": 791,
#           "pos": "NN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 9,
#           "word": "and",
#           "originalText": "and",
#           "lemma": "and",
#           "characterOffsetBegin": 792,
#           "characterOffsetEnd": 795,
#           "pos": "CC",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 10,
#           "word": "clearing",
#           "originalText": "clearing",
#           "lemma": "clearing",
#           "characterOffsetBegin": 796,
#           "characterOffsetEnd": 804,
#           "pos": "NN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 11,
#           "word": "land",
#           "originalText": "land",
#           "lemma": "land",
#           "characterOffsetBegin": 805,
#           "characterOffsetEnd": 809,
#           "pos": "NN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 12,
#           "word": "around",
#           "originalText": "around",
#           "lemma": "around",
#           "characterOffsetBegin": 810,
#           "characterOffsetEnd": 816,
#           "pos": "IN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 13,
#           "word": "Rio",
#           "originalText": "Rio",
#           "lemma": "Rio",
#           "characterOffsetBegin": 817,
#           "characterOffsetEnd": 820,
#           "pos": "NNP",
#           "ner": "LOCATION",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 14,
#           "word": "Cristalino",
#           "originalText": "Cristalino",
#           "lemma": "Cristalino",
#           "characterOffsetBegin": 821,
#           "characterOffsetEnd": 831,
#           "pos": "NNP",
#           "ner": "LOCATION",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 15,
#           "word": "and",
#           "originalText": "and",
#           "lemma": "and",
#           "characterOffsetBegin": 832,
#           "characterOffsetEnd": 835,
#           "pos": "CC",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 16,
#           "word": "planting",
#           "originalText": "planting",
#           "lemma": "plant",
#           "characterOffsetBegin": 836,
#           "characterOffsetEnd": 844,
#           "pos": "VBG",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 17,
#           "word": "it",
#           "originalText": "it",
#           "lemma": "it",
#           "characterOffsetBegin": 845,
#           "characterOffsetEnd": 847,
#           "pos": "PRP",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 18,
#           "word": "with",
#           "originalText": "with",
#           "lemma": "with",
#           "characterOffsetBegin": 848,
#           "characterOffsetEnd": 852,
#           "pos": "IN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 19,
#           "word": "coffee",
#           "originalText": "coffee",
#           "lemma": "coffee",
#           "characterOffsetBegin": 853,
#           "characterOffsetEnd": 859,
#           "pos": "NN",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": " ",
#           "after": ""
#         },
#         {
#           "index": 20,
#           "word": ".",
#           "originalText": ".",
#           "lemma": ".",
#           "characterOffsetBegin": 859,
#           "characterOffsetEnd": 860,
#           "pos": ".",
#           "ner": "O",
#           "speaker": "PER0",
#           "before": "",
#           "after": ""
#         }
#       ]
#     }
#   ],
#   "corefs": {
#     "36": [
#       {
#         "id": 0,
#         "text": "She",
#         "type": "PRONOMINAL",
#         "number": "SINGULAR",
#         "gender": "FEMALE",
#         "animacy": "ANIMATE",
#         "startIndex": 1,
#         "endIndex": 2,
#         "headIndex": 1,
#         "sentNum": 1,
#         "position": [
#           1,
#           1
#         ],
#         "isRepresentativeMention": true
#       },
#       {
#         "id": 2,
#         "text": "Her",
#         "type": "PRONOMINAL",
#         "number": "SINGULAR",
#         "gender": "FEMALE",
#         "animacy": "ANIMATE",
#         "startIndex": 1,
#         "endIndex": 2,
#         "headIndex": 1,
#         "sentNum": 2,
#         "position": [
#           2,
#           1
#         ],
#         "isRepresentativeMention": false
#       },
#       {
#         "id": 25,
#         "text": "she",
#         "type": "PRONOMINAL",
#         "number": "SINGULAR",
#         "gender": "FEMALE",
#         "animacy": "ANIMATE",
#         "startIndex": 7,
#         "endIndex": 8,
#         "headIndex": 7,
#         "sentNum": 5,
#         "position": [
#           5,
#           2
#         ],
#         "isRepresentativeMention": false
#       },
#       {
#         "id": 31,
#         "text": "her",
#         "type": "PRONOMINAL",
#         "number": "SINGULAR",
#         "gender": "FEMALE",
#         "animacy": "ANIMATE",
#         "startIndex": 2,
#         "endIndex": 3,
#         "headIndex": 2,
#         "sentNum": 6,
#         "position": [
#           6,
#           5
#         ],
#         "isRepresentativeMention": false
#       },
#       {
#         "id": 39,
#         "text": "she",
#         "type": "PRONOMINAL",
#         "number": "SINGULAR",
#         "gender": "FEMALE",
#         "animacy": "ANIMATE",
#         "startIndex": 3,
#         "endIndex": 4,
#         "headIndex": 3,
#         "sentNum": 7,
#         "position": [
#           7,
#           6
#         ],
#         "isRepresentativeMention": false
#       },
#       {
#         "id": 36,
#         "text": "her",
#         "type": "PRONOMINAL",
#         "number": "SINGULAR",
#         "gender": "FEMALE",
#         "animacy": "ANIMATE",
#         "startIndex": 23,
#         "endIndex": 24,
#         "headIndex": 23,
#         "sentNum": 7,
#         "position": [
#           7,
#           3
#         ],
#         "isRepresentativeMention": false
#       },
#       {
#         "id": 44,
#         "text": "her",
#         "type": "PRONOMINAL",
#         "number": "SINGULAR",
#         "gender": "FEMALE",
#         "animacy": "ANIMATE",
#         "startIndex": 3,
#         "endIndex": 4,
#         "headIndex": 3,
#         "sentNum": 8,
#         "position": [
#           8,
#           3
#         ],
#         "isRepresentativeMention": false
#       },
#       {
#         "id": 50,
#         "text": "Her",
#         "type": "PRONOMINAL",
#         "number": "SINGULAR",
#         "gender": "FEMALE",
#         "animacy": "ANIMATE",
#         "startIndex": 1,
#         "endIndex": 2,
#         "headIndex": 1,
#         "sentNum": 9,
#         "position": [
#           9,
#           2
#         ],
#         "isRepresentativeMention": false
#       }
#     ],
#     "23": [
#       {
#         "id": 3,
#         "text": "Her umbrella",
#         "type": "NOMINAL",
#         "number": "SINGULAR",
#         "gender": "NEUTRAL",
#         "animacy": "INANIMATE",
#         "startIndex": 1,
#         "endIndex": 3,
#         "headIndex": 2,
#         "sentNum": 2,
#         "position": [
#           2,
#           2
#         ],
#         "isRepresentativeMention": true
#       },
#       {
#         "id": 4,
#         "text": "its",
#         "type": "PRONOMINAL",
#         "number": "SINGULAR",
#         "gender": "UNKNOWN",
#         "animacy": "INANIMATE",
#         "startIndex": 4,
#         "endIndex": 5,
#         "headIndex": 4,
#         "sentNum": 2,
#         "position": [
#           2,
#           3
#         ],
#         "isRepresentativeMention": false
#       },
#       {
#         "id": 11,
#         "text": "its",
#         "type": "PRONOMINAL",
#         "number": "SINGULAR",
#         "gender": "UNKNOWN",
#         "animacy": "INANIMATE",
#         "startIndex": 23,
#         "endIndex": 24,
#         "headIndex": 23,
#         "sentNum": 2,
#         "position": [
#           2,
#           10
#         ],
#         "isRepresentativeMention": false
#       },
#       {
#         "id": 23,
#         "text": "its",
#         "type": "PRONOMINAL",
#         "number": "SINGULAR",
#         "gender": "UNKNOWN",
#         "animacy": "INANIMATE",
#         "startIndex": 8,
#         "endIndex": 9,
#         "headIndex": 8,
#         "sentNum": 4,
#         "position": [
#           4,
#           8
#         ],
#         "isRepresentativeMention": false
#       }
#     ],
#     "55": [
#       {
#         "id": 52,
#         "text": "some success through buying and clearing land around Rio Cristalino",
#         "type": "NOMINAL",
#         "number": "SINGULAR",
#         "gender": "NEUTRAL",
#         "animacy": "INANIMATE",
#         "startIndex": 5,
#         "endIndex": 15,
#         "headIndex": 6,
#         "sentNum": 9,
#         "position": [
#           9,
#           4
#         ],
#         "isRepresentativeMention": true
#       },
#       {
#         "id": 55,
#         "text": "it",
#         "type": "PRONOMINAL",
#         "number": "SINGULAR",
#         "gender": "NEUTRAL",
#         "animacy": "INANIMATE",
#         "startIndex": 17,
#         "endIndex": 18,
#         "headIndex": 17,
#         "sentNum": 9,
#         "position": [
#           9,
#           7
#         ],
#         "isRepresentativeMention": false
#       }
#     ],
#     "24": [
#       {
#         "id": 22,
#         "text": "a car",
#         "type": "NOMINAL",
#         "number": "SINGULAR",
#         "gender": "NEUTRAL",
#         "animacy": "INANIMATE",
#         "startIndex": 2,
#         "endIndex": 4,
#         "headIndex": 3,
#         "sentNum": 4,
#         "position": [
#           4,
#           7
#         ],
#         "isRepresentativeMention": true
#       },
#       {
#         "id": 24,
#         "text": "it",
#         "type": "PRONOMINAL",
#         "number": "SINGULAR",
#         "gender": "NEUTRAL",
#         "animacy": "INANIMATE",
#         "startIndex": 2,
#         "endIndex": 3,
#         "headIndex": 2,
#         "sentNum": 5,
#         "position": [
#           5,
#           1
#         ],
#         "isRepresentativeMention": false
#       }
#     ]
#   }
# }

# %% [markdown]
# ### c. Sentiment Analysis

# %%
res = nlp.annotate(text,
                   properties={
                       'annotators': 'sentiment',
#                        'outputFormat': 'json',
                       'timeout': 30000,
                   })

# %%
print(res)
# Out:
# {
#   "sentences": [
#     {
#       "index": 0,
#       "parse": "(ROOT\r\n  (S\r\n    (S\r\n      (NP (PRP She))\r\n      (VP (VBD was)\r\n        (VP (VBG walking)\r\n          (ADVP (RB lazily)))))\r\n    (, ,)\r\n    (S\r\n      (PP (IN for)\r\n        (NP (DT the) (JJ fierce) (NNP April) (NN sun)))\r\n      (VP (VBD was)\r\n        (ADJP (RB directly) (JJ overhead))))\r\n    (. .)))",
#       "basicDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 3,
#           "dependentGloss": "walking"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 1,
#           "dependentGloss": "She"
#         },
#         {
#           "dep": "aux",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 2,
#           "dependentGloss": "was"
#         },
#         {
#           "dep": "advmod",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 4,
#           "dependentGloss": "lazily"
#         },
#         {
#           "dep": "punct",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 5,
#           "dependentGloss": ","
#         },
#         {
#           "dep": "case",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 6,
#           "dependentGloss": "for"
#         },
#         {
#           "dep": "det",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 7,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "amod",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 8,
#           "dependentGloss": "fierce"
#         },
#         {
#           "dep": "compound",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 9,
#           "dependentGloss": "April"
#         },
#         {
#           "dep": "nmod",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 10,
#           "dependentGloss": "sun"
#         },
#         {
#           "dep": "cop",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 11,
#           "dependentGloss": "was"
#         },
#         {
#           "dep": "advmod",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 12,
#           "dependentGloss": "directly"
#         },
#         {
#           "dep": "parataxis",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 13,
#           "dependentGloss": "overhead"
#         },
#         {
#           "dep": "punct",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 14,
#           "dependentGloss": "."
#         }
#       ],
#       "enhancedDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 3,
#           "dependentGloss": "walking"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 1,
#           "dependentGloss": "She"
#         },
#         {
#           "dep": "aux",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 2,
#           "dependentGloss": "was"
#         },
#         {
#           "dep": "advmod",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 4,
#           "dependentGloss": "lazily"
#         },
#         {
#           "dep": "punct",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 5,
#           "dependentGloss": ","
#         },
#         {
#           "dep": "case",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 6,
#           "dependentGloss": "for"
#         },
#         {
#           "dep": "det",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 7,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "amod",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 8,
#           "dependentGloss": "fierce"
#         },
#         {
#           "dep": "compound",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 9,
#           "dependentGloss": "April"
#         },
#         {
#           "dep": "nmod:for",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 10,
#           "dependentGloss": "sun"
#         },
#         {
#           "dep": "cop",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 11,
#           "dependentGloss": "was"
#         },
#         {
#           "dep": "advmod",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 12,
#           "dependentGloss": "directly"
#         },
#         {
#           "dep": "parataxis",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 13,
#           "dependentGloss": "overhead"
#         },
#         {
#           "dep": "punct",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 14,
#           "dependentGloss": "."
#         }
#       ],
#       "enhancedPlusPlusDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 3,
#           "dependentGloss": "walking"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 1,
#           "dependentGloss": "She"
#         },
#         {
#           "dep": "aux",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 2,
#           "dependentGloss": "was"
#         },
#         {
#           "dep": "advmod",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 4,
#           "dependentGloss": "lazily"
#         },
#         {
#           "dep": "punct",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 5,
#           "dependentGloss": ","
#         },
#         {
#           "dep": "case",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 6,
#           "dependentGloss": "for"
#         },
#         {
#           "dep": "det",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 7,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "amod",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 8,
#           "dependentGloss": "fierce"
#         },
#         {
#           "dep": "compound",
#           "governor": 10,
#           "governorGloss": "sun",
#           "dependent": 9,
#           "dependentGloss": "April"
#         },
#         {
#           "dep": "nmod:for",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 10,
#           "dependentGloss": "sun"
#         },
#         {
#           "dep": "cop",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 11,
#           "dependentGloss": "was"
#         },
#         {
#           "dep": "advmod",
#           "governor": 13,
#           "governorGloss": "overhead",
#           "dependent": 12,
#           "dependentGloss": "directly"
#         },
#         {
#           "dep": "parataxis",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 13,
#           "dependentGloss": "overhead"
#         },
#         {
#           "dep": "punct",
#           "governor": 3,
#           "governorGloss": "walking",
#           "dependent": 14,
#           "dependentGloss": "."
#         }
#       ],
#       "sentimentValue": "1",
#       "sentiment": "Negative",
#       "sentimentDistribution": [
#         0.07533003140597,
#         0.40077895104596,
#         0.35135064958332,
#         0.13962853249119,
#         0.03291183547357
#       ],
#       "sentimentTree": "(ROOT|sentiment=1|prob=0.401\r\n  (@S|sentiment=2|prob=0.420\r\n    (@S|sentiment=2|prob=0.693\r\n      (S|sentiment=2|prob=0.941 (NP|sentiment=2|prob=0.991 She)\r\n        (VP|sentiment=2|prob=0.797 (VBD|sentiment=2|prob=0.996 was)\r\n          (VP|sentiment=2|prob=0.806 (VBG|sentiment=2|prob=0.955 walking) (ADVP|sentiment=1|prob=0.660 lazily))))\r\n      (,|sentiment=2|prob=0.997 ,))\r\n    (S|sentiment=2|prob=0.598\r\n      (PP|sentiment=2|prob=0.677 (IN|sentiment=2|prob=0.992 for)\r\n        (NP|sentiment=2|prob=0.598 (DT|sentiment=2|prob=0.994 the)\r\n          (@NP|sentiment=2|prob=0.485 (JJ|sentiment=3|prob=0.781 fierce)\r\n            (@NP|sentiment=2|prob=0.714 (NNP|sentiment=3|prob=0.429 April) (NN|sentiment=2|prob=0.815 sun)))))\r\n      (VP|sentiment=2|prob=0.747 (VBD|sentiment=2|prob=0.996 was)\r\n        (ADJP|sentiment=2|prob=0.844 (RB|sentiment=2|prob=0.969 directly) (JJ|sentiment=2|prob=0.631 overhead)))))\r\n  (.|sentiment=2|prob=0.997 .))",
#       "tokens": [
#         {
#           "index": 1,
#           "word": "She",
#           "originalText": "She",
#           "characterOffsetBegin": 0,
#           "characterOffsetEnd": 3,
#           "pos": "PRP",
#           "before": "",
#           "after": " "
#         },
#         {
#           "index": 2,
#           "word": "was",
#           "originalText": "was",
#           "characterOffsetBegin": 4,
#           "characterOffsetEnd": 7,
#           "pos": "VBD",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 3,
#           "word": "walking",
#           "originalText": "walking",
#           "characterOffsetBegin": 8,
#           "characterOffsetEnd": 15,
#           "pos": "VBG",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 4,
#           "word": "lazily",
#           "originalText": "lazily",
#           "characterOffsetBegin": 16,
#           "characterOffsetEnd": 22,
#           "pos": "RB",
#           "before": " ",
#           "after": ""
#         },
#         {
#           "index": 5,
#           "word": ",",
#           "originalText": ",",
#           "characterOffsetBegin": 22,
#           "characterOffsetEnd": 23,
#           "pos": ",",
#           "before": "",
#           "after": " "
#         },
#         {
#           "index": 6,
#           "word": "for",
#           "originalText": "for",
#           "characterOffsetBegin": 24,
#           "characterOffsetEnd": 27,
#           "pos": "IN",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 7,
#           "word": "the",
#           "originalText": "the",
#           "characterOffsetBegin": 28,
#           "characterOffsetEnd": 31,
#           "pos": "DT",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 8,
#           "word": "fierce",
#           "originalText": "fierce",
#           "characterOffsetBegin": 32,
#           "characterOffsetEnd": 38,
#           "pos": "JJ",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 9,
#           "word": "April",
#           "originalText": "April",
#           "characterOffsetBegin": 39,
#           "characterOffsetEnd": 44,
#           "pos": "NNP",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 10,
#           "word": "sun",
#           "originalText": "sun",
#           "characterOffsetBegin": 45,
#           "characterOffsetEnd": 48,
#           "pos": "NN",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 11,
#           "word": "was",
#           "originalText": "was",
#           "characterOffsetBegin": 49,
#           "characterOffsetEnd": 52,
#           "pos": "VBD",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 12,
#           "word": "directly",
#           "originalText": "directly",
#           "characterOffsetBegin": 53,
#           "characterOffsetEnd": 61,
#           "pos": "RB",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 13,
#           "word": "overhead",
#           "originalText": "overhead",
#           "characterOffsetBegin": 62,
#           "characterOffsetEnd": 70,
#           "pos": "JJ",
#           "before": " ",
#           "after": ""
#         },
#         {
#           "index": 14,
#           "word": ".",
#           "originalText": ".",
#           "characterOffsetBegin": 70,
#           "characterOffsetEnd": 71,
#           "pos": ".",
#           "before": "",
#           "after": " "
#         }
#       ]
#     },
#     {
#       "index": 1,
#       "parse": "(ROOT\r\n  (S\r\n    (NP (PRP$ Her) (NN umbrella))\r\n    (VP\r\n      (VP (VBD blocked)\r\n        (NP (PRP$ its) (NNS rays)))\r\n      (CC but)\r\n      (NP\r\n        (NP (NN nothing))\r\n        (VP (VBD blocked)\r\n          (NP\r\n            (NP (DT the) (NN heat))\r\n            (: -)\r\n            (NP\r\n              (NP (DT the) (NN sort))\r\n              (PP (IN of)\r\n                (NP (JJ raw) (, ,) (JJ wild) (NN heat)))\r\n              (SBAR\r\n                (WHNP (WDT that))\r\n                (S\r\n                  (VP (VBZ crushes)\r\n                    (NP (PRP you))\r\n                    (PP (IN with)\r\n                      (NP (PRP$ its) (NN energy)))))))))))\r\n    (. .)))",
#       "basicDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 3,
#           "dependentGloss": "blocked"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 2,
#           "governorGloss": "umbrella",
#           "dependent": 1,
#           "dependentGloss": "Her"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 2,
#           "dependentGloss": "umbrella"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 5,
#           "governorGloss": "rays",
#           "dependent": 4,
#           "dependentGloss": "its"
#         },
#         {
#           "dep": "dobj",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 5,
#           "dependentGloss": "rays"
#         },
#         {
#           "dep": "cc",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 6,
#           "dependentGloss": "but"
#         },
#         {
#           "dep": "conj",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 7,
#           "dependentGloss": "nothing"
#         },
#         {
#           "dep": "acl",
#           "governor": 7,
#           "governorGloss": "nothing",
#           "dependent": 8,
#           "dependentGloss": "blocked"
#         },
#         {
#           "dep": "det",
#           "governor": 10,
#           "governorGloss": "heat",
#           "dependent": 9,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "dobj",
#           "governor": 8,
#           "governorGloss": "blocked",
#           "dependent": 10,
#           "dependentGloss": "heat"
#         },
#         {
#           "dep": "punct",
#           "governor": 10,
#           "governorGloss": "heat",
#           "dependent": 11,
#           "dependentGloss": "-"
#         },
#         {
#           "dep": "det",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 12,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "dep",
#           "governor": 10,
#           "governorGloss": "heat",
#           "dependent": 13,
#           "dependentGloss": "sort"
#         },
#         {
#           "dep": "case",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 14,
#           "dependentGloss": "of"
#         },
#         {
#           "dep": "amod",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 15,
#           "dependentGloss": "raw"
#         },
#         {
#           "dep": "punct",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 16,
#           "dependentGloss": ","
#         },
#         {
#           "dep": "amod",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 17,
#           "dependentGloss": "wild"
#         },
#         {
#           "dep": "nmod",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 18,
#           "dependentGloss": "heat"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 20,
#           "governorGloss": "crushes",
#           "dependent": 19,
#           "dependentGloss": "that"
#         },
#         {
#           "dep": "acl:relcl",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 20,
#           "dependentGloss": "crushes"
#         },
#         {
#           "dep": "dobj",
#           "governor": 20,
#           "governorGloss": "crushes",
#           "dependent": 21,
#           "dependentGloss": "you"
#         },
#         {
#           "dep": "case",
#           "governor": 24,
#           "governorGloss": "energy",
#           "dependent": 22,
#           "dependentGloss": "with"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 24,
#           "governorGloss": "energy",
#           "dependent": 23,
#           "dependentGloss": "its"
#         },
#         {
#           "dep": "nmod",
#           "governor": 20,
#           "governorGloss": "crushes",
#           "dependent": 24,
#           "dependentGloss": "energy"
#         },
#         {
#           "dep": "punct",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 25,
#           "dependentGloss": "."
#         }
#       ],
#       "enhancedDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 3,
#           "dependentGloss": "blocked"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 2,
#           "governorGloss": "umbrella",
#           "dependent": 1,
#           "dependentGloss": "Her"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 2,
#           "dependentGloss": "umbrella"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 5,
#           "governorGloss": "rays",
#           "dependent": 4,
#           "dependentGloss": "its"
#         },
#         {
#           "dep": "dobj",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 5,
#           "dependentGloss": "rays"
#         },
#         {
#           "dep": "cc",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 6,
#           "dependentGloss": "but"
#         },
#         {
#           "dep": "conj:but",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 7,
#           "dependentGloss": "nothing"
#         },
#         {
#           "dep": "acl",
#           "governor": 7,
#           "governorGloss": "nothing",
#           "dependent": 8,
#           "dependentGloss": "blocked"
#         },
#         {
#           "dep": "det",
#           "governor": 10,
#           "governorGloss": "heat",
#           "dependent": 9,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "dobj",
#           "governor": 8,
#           "governorGloss": "blocked",
#           "dependent": 10,
#           "dependentGloss": "heat"
#         },
#         {
#           "dep": "punct",
#           "governor": 10,
#           "governorGloss": "heat",
#           "dependent": 11,
#           "dependentGloss": "-"
#         },
#         {
#           "dep": "det",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 12,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "dep",
#           "governor": 10,
#           "governorGloss": "heat",
#           "dependent": 13,
#           "dependentGloss": "sort"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 20,
#           "governorGloss": "crushes",
#           "dependent": 13,
#           "dependentGloss": "sort"
#         },
#         {
#           "dep": "case",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 14,
#           "dependentGloss": "of"
#         },
#         {
#           "dep": "amod",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 15,
#           "dependentGloss": "raw"
#         },
#         {
#           "dep": "punct",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 16,
#           "dependentGloss": ","
#         },
#         {
#           "dep": "amod",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 17,
#           "dependentGloss": "wild"
#         },
#         {
#           "dep": "nmod:of",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 18,
#           "dependentGloss": "heat"
#         },
#         {
#           "dep": "ref",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 19,
#           "dependentGloss": "that"
#         },
#         {
#           "dep": "acl:relcl",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 20,
#           "dependentGloss": "crushes"
#         },
#         {
#           "dep": "dobj",
#           "governor": 20,
#           "governorGloss": "crushes",
#           "dependent": 21,
#           "dependentGloss": "you"
#         },
#         {
#           "dep": "case",
#           "governor": 24,
#           "governorGloss": "energy",
#           "dependent": 22,
#           "dependentGloss": "with"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 24,
#           "governorGloss": "energy",
#           "dependent": 23,
#           "dependentGloss": "its"
#         },
#         {
#           "dep": "nmod:with",
#           "governor": 20,
#           "governorGloss": "crushes",
#           "dependent": 24,
#           "dependentGloss": "energy"
#         },
#         {
#           "dep": "punct",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 25,
#           "dependentGloss": "."
#         }
#       ],
#       "enhancedPlusPlusDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 3,
#           "dependentGloss": "blocked"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 2,
#           "governorGloss": "umbrella",
#           "dependent": 1,
#           "dependentGloss": "Her"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 2,
#           "dependentGloss": "umbrella"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 5,
#           "governorGloss": "rays",
#           "dependent": 4,
#           "dependentGloss": "its"
#         },
#         {
#           "dep": "dobj",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 5,
#           "dependentGloss": "rays"
#         },
#         {
#           "dep": "cc",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 6,
#           "dependentGloss": "but"
#         },
#         {
#           "dep": "conj:but",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 7,
#           "dependentGloss": "nothing"
#         },
#         {
#           "dep": "acl",
#           "governor": 7,
#           "governorGloss": "nothing",
#           "dependent": 8,
#           "dependentGloss": "blocked"
#         },
#         {
#           "dep": "det",
#           "governor": 10,
#           "governorGloss": "heat",
#           "dependent": 9,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "dobj",
#           "governor": 8,
#           "governorGloss": "blocked",
#           "dependent": 10,
#           "dependentGloss": "heat"
#         },
#         {
#           "dep": "punct",
#           "governor": 10,
#           "governorGloss": "heat",
#           "dependent": 11,
#           "dependentGloss": "-"
#         },
#         {
#           "dep": "det",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 12,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "dep",
#           "governor": 10,
#           "governorGloss": "heat",
#           "dependent": 13,
#           "dependentGloss": "sort"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 20,
#           "governorGloss": "crushes",
#           "dependent": 13,
#           "dependentGloss": "sort"
#         },
#         {
#           "dep": "case",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 14,
#           "dependentGloss": "of"
#         },
#         {
#           "dep": "amod",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 15,
#           "dependentGloss": "raw"
#         },
#         {
#           "dep": "punct",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 16,
#           "dependentGloss": ","
#         },
#         {
#           "dep": "amod",
#           "governor": 18,
#           "governorGloss": "heat",
#           "dependent": 17,
#           "dependentGloss": "wild"
#         },
#         {
#           "dep": "nmod:of",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 18,
#           "dependentGloss": "heat"
#         },
#         {
#           "dep": "ref",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 19,
#           "dependentGloss": "that"
#         },
#         {
#           "dep": "acl:relcl",
#           "governor": 13,
#           "governorGloss": "sort",
#           "dependent": 20,
#           "dependentGloss": "crushes"
#         },
#         {
#           "dep": "dobj",
#           "governor": 20,
#           "governorGloss": "crushes",
#           "dependent": 21,
#           "dependentGloss": "you"
#         },
#         {
#           "dep": "case",
#           "governor": 24,
#           "governorGloss": "energy",
#           "dependent": 22,
#           "dependentGloss": "with"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 24,
#           "governorGloss": "energy",
#           "dependent": 23,
#           "dependentGloss": "its"
#         },
#         {
#           "dep": "nmod:with",
#           "governor": 20,
#           "governorGloss": "crushes",
#           "dependent": 24,
#           "dependentGloss": "energy"
#         },
#         {
#           "dep": "punct",
#           "governor": 3,
#           "governorGloss": "blocked",
#           "dependent": 25,
#           "dependentGloss": "."
#         }
#       ],
#       "sentimentValue": "3",
#       "sentiment": "Positive",
#       "sentimentDistribution": [
#         0.06618920306661,
#         0.22990219540589,
#         0.21625701831394,
#         0.37485382032649,
#         0.11279776288707
#       ],
#       "sentimentTree": "(ROOT|sentiment=3|prob=0.375\r\n  (NP|sentiment=2|prob=0.785 (PRP$|sentiment=2|prob=0.988 Her) (NN|sentiment=2|prob=0.631 umbrella))\r\n  (@S|sentiment=3|prob=0.415\r\n    (VP|sentiment=3|prob=0.350\r\n      (@VP|sentiment=2|prob=0.729\r\n        (VP|sentiment=2|prob=0.531 (VBD|sentiment=2|prob=0.631 blocked)\r\n          (NP|sentiment=2|prob=0.795 (PRP$|sentiment=2|prob=0.994 its) (NNS|sentiment=2|prob=0.631 rays)))\r\n        (CC|sentiment=2|prob=0.990 but))\r\n      (NP|sentiment=3|prob=0.606 (NP|sentiment=1|prob=0.936 nothing)\r\n        (VP|sentiment=3|prob=0.680 (VBD|sentiment=2|prob=0.631 blocked)\r\n          (NP|sentiment=3|prob=0.750\r\n            (@NP|sentiment=2|prob=0.885\r\n              (NP|sentiment=2|prob=0.975 (DT|sentiment=2|prob=0.994 the) (NN|sentiment=2|prob=0.988 heat))\r\n              (:|sentiment=2|prob=0.996 -))\r\n            (NP|sentiment=3|prob=0.757\r\n              (@NP|sentiment=3|prob=0.753\r\n                (NP|sentiment=2|prob=0.994 (DT|sentiment=2|prob=0.994 the) (NN|sentiment=2|prob=0.996 sort))\r\n                (PP|sentiment=3|prob=0.799 (IN|sentiment=2|prob=0.993 of)\r\n                  (NP|sentiment=3|prob=0.801 (JJ|sentiment=2|prob=0.981 raw)\r\n                    (@NP|sentiment=2|prob=0.462 (,|sentiment=2|prob=0.997 ,)\r\n                      (@NP|sentiment=3|prob=0.707 (JJ|sentiment=2|prob=0.975 wild) (NN|sentiment=2|prob=0.988 heat))))))\r\n              (SBAR|sentiment=3|prob=0.627 (WHNP|sentiment=2|prob=0.991 that)\r\n                (S|sentiment=3|prob=0.611\r\n                  (@VP|sentiment=2|prob=0.759 (VBZ|sentiment=2|prob=0.678 crushes) (NP|sentiment=2|prob=0.995 you))\r\n                  (PP|sentiment=3|prob=0.745 (IN|sentiment=2|prob=0.992 with)\r\n                    (NP|sentiment=2|prob=0.560 (PRP$|sentiment=2|prob=0.994 its) (NN|sentiment=3|prob=0.976 energy))))))))))\r\n    (.|sentiment=2|prob=0.997 .)))",
#       "tokens": [
#         {
#           "index": 1,
#           "word": "Her",
#           "originalText": "Her",
#           "characterOffsetBegin": 72,
#           "characterOffsetEnd": 75,
#           "pos": "PRP$",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 2,
#           "word": "umbrella",
#           "originalText": "umbrella",
#           "characterOffsetBegin": 76,
#           "characterOffsetEnd": 84,
#           "pos": "NN",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 3,
#           "word": "blocked",
#           "originalText": "blocked",
#           "characterOffsetBegin": 85,
#           "characterOffsetEnd": 92,
#           "pos": "VBD",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 4,
#           "word": "its",
#           "originalText": "its",
#           "characterOffsetBegin": 93,
#           "characterOffsetEnd": 96,
#           "pos": "PRP$",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 5,
#           "word": "rays",
#           "originalText": "rays",
#           "characterOffsetBegin": 97,
#           "characterOffsetEnd": 101,
#           "pos": "NNS",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 6,
#           "word": "but",
#           "originalText": "but",
#           "characterOffsetBegin": 102,
#           "characterOffsetEnd": 105,
#           "pos": "CC",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 7,
#           "word": "nothing",
#           "originalText": "nothing",
#           "characterOffsetBegin": 106,
#           "characterOffsetEnd": 113,
#           "pos": "NN",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 8,
#           "word": "blocked",
#           "originalText": "blocked",
#           "characterOffsetBegin": 114,
#           "characterOffsetEnd": 121,
#           "pos": "VBD",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 9,
#           "word": "the",
#           "originalText": "the",
#           "characterOffsetBegin": 122,
#           "characterOffsetEnd": 125,
#           "pos": "DT",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 10,
#           "word": "heat",
#           "originalText": "heat",
#           "characterOffsetBegin": 126,
#           "characterOffsetEnd": 130,
#           "pos": "NN",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 11,
#           "word": "-",
#           "originalText": "-",
#           "characterOffsetBegin": 131,
#           "characterOffsetEnd": 132,
#           "pos": ":",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 12,
#           "word": "the",
#           "originalText": "the",
#           "characterOffsetBegin": 133,
#           "characterOffsetEnd": 136,
#           "pos": "DT",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 13,
#           "word": "sort",
#           "originalText": "sort",
#           "characterOffsetBegin": 137,
#           "characterOffsetEnd": 141,
#           "pos": "NN",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 14,
#           "word": "of",
#           "originalText": "of",
#           "characterOffsetBegin": 142,
#           "characterOffsetEnd": 144,
#           "pos": "IN",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 15,
#           "word": "raw",
#           "originalText": "raw",
#           "characterOffsetBegin": 145,
#           "characterOffsetEnd": 148,
#           "pos": "JJ",
#           "before": " ",
#           "after": ""
#         },
#         {
#           "index": 16,
#           "word": ",",
#           "originalText": ",",
#           "characterOffsetBegin": 148,
#           "characterOffsetEnd": 149,
#           "pos": ",",
#           "before": "",
#           "after": " "
#         },
#         {
#           "index": 17,
#           "word": "wild",
#           "originalText": "wild",
#           "characterOffsetBegin": 150,
#           "characterOffsetEnd": 154,
#           "pos": "JJ",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 18,
#           "word": "heat",
#           "originalText": "heat",
#           "characterOffsetBegin": 155,
#           "characterOffsetEnd": 159,
#           "pos": "NN",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 19,
#           "word": "that",
#           "originalText": "that",
#           "characterOffsetBegin": 160,
#           "characterOffsetEnd": 164,
#           "pos": "WDT",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 20,
#           "word": "crushes",
#           "originalText": "crushes",
#           "characterOffsetBegin": 165,
#           "characterOffsetEnd": 172,
#           "pos": "VBZ",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 21,
#           "word": "you",
#           "originalText": "you",
#           "characterOffsetBegin": 173,
#           "characterOffsetEnd": 176,
#           "pos": "PRP",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 22,
#           "word": "with",
#           "originalText": "with",
#           "characterOffsetBegin": 177,
#           "characterOffsetEnd": 181,
#           "pos": "IN",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 23,
#           "word": "its",
#           "originalText": "its",
#           "characterOffsetBegin": 182,
#           "characterOffsetEnd": 185,
#           "pos": "PRP$",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 24,
#           "word": "energy",
#           "originalText": "energy",
#           "characterOffsetBegin": 186,
#           "characterOffsetEnd": 192,
#           "pos": "NN",
#           "before": " ",
#           "after": ""
#         },
#         {
#           "index": 25,
#           "word": ".",
#           "originalText": ".",
#           "characterOffsetBegin": 192,
#           "characterOffsetEnd": 193,
#           "pos": ".",
#           "before": "",
#           "after": " "
#         }
#       ]
#     },
#     {
#       "index": 2,
#       "parse": "(ROOT\r\n  (S\r\n    (NP (DT A) (JJ few) (NN buffalo))\r\n    (VP (VBD were)\r\n      (ADJP (JJ tethered))\r\n      (PP (IN under)\r\n        (NP (NNS coconuts)))\r\n      (, ,)\r\n      (S\r\n        (VP (VBG browsing)\r\n          (NP (DT the) (JJ parched) (NNS verges)))))\r\n    (. .)))",
#       "basicDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 5,
#           "dependentGloss": "tethered"
#         },
#         {
#           "dep": "det",
#           "governor": 3,
#           "governorGloss": "buffalo",
#           "dependent": 1,
#           "dependentGloss": "A"
#         },
#         {
#           "dep": "amod",
#           "governor": 3,
#           "governorGloss": "buffalo",
#           "dependent": 2,
#           "dependentGloss": "few"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 3,
#           "dependentGloss": "buffalo"
#         },
#         {
#           "dep": "cop",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 4,
#           "dependentGloss": "were"
#         },
#         {
#           "dep": "case",
#           "governor": 7,
#           "governorGloss": "coconuts",
#           "dependent": 6,
#           "dependentGloss": "under"
#         },
#         {
#           "dep": "nmod",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 7,
#           "dependentGloss": "coconuts"
#         },
#         {
#           "dep": "punct",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 8,
#           "dependentGloss": ","
#         },
#         {
#           "dep": "xcomp",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 9,
#           "dependentGloss": "browsing"
#         },
#         {
#           "dep": "det",
#           "governor": 12,
#           "governorGloss": "verges",
#           "dependent": 10,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "amod",
#           "governor": 12,
#           "governorGloss": "verges",
#           "dependent": 11,
#           "dependentGloss": "parched"
#         },
#         {
#           "dep": "dobj",
#           "governor": 9,
#           "governorGloss": "browsing",
#           "dependent": 12,
#           "dependentGloss": "verges"
#         },
#         {
#           "dep": "punct",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 13,
#           "dependentGloss": "."
#         }
#       ],
#       "enhancedDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 5,
#           "dependentGloss": "tethered"
#         },
#         {
#           "dep": "det",
#           "governor": 3,
#           "governorGloss": "buffalo",
#           "dependent": 1,
#           "dependentGloss": "A"
#         },
#         {
#           "dep": "amod",
#           "governor": 3,
#           "governorGloss": "buffalo",
#           "dependent": 2,
#           "dependentGloss": "few"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 3,
#           "dependentGloss": "buffalo"
#         },
#         {
#           "dep": "cop",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 4,
#           "dependentGloss": "were"
#         },
#         {
#           "dep": "case",
#           "governor": 7,
#           "governorGloss": "coconuts",
#           "dependent": 6,
#           "dependentGloss": "under"
#         },
#         {
#           "dep": "nmod:under",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 7,
#           "dependentGloss": "coconuts"
#         },
#         {
#           "dep": "punct",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 8,
#           "dependentGloss": ","
#         },
#         {
#           "dep": "xcomp",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 9,
#           "dependentGloss": "browsing"
#         },
#         {
#           "dep": "det",
#           "governor": 12,
#           "governorGloss": "verges",
#           "dependent": 10,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "amod",
#           "governor": 12,
#           "governorGloss": "verges",
#           "dependent": 11,
#           "dependentGloss": "parched"
#         },
#         {
#           "dep": "dobj",
#           "governor": 9,
#           "governorGloss": "browsing",
#           "dependent": 12,
#           "dependentGloss": "verges"
#         },
#         {
#           "dep": "punct",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 13,
#           "dependentGloss": "."
#         }
#       ],
#       "enhancedPlusPlusDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 5,
#           "dependentGloss": "tethered"
#         },
#         {
#           "dep": "det",
#           "governor": 3,
#           "governorGloss": "buffalo",
#           "dependent": 1,
#           "dependentGloss": "A"
#         },
#         {
#           "dep": "amod",
#           "governor": 3,
#           "governorGloss": "buffalo",
#           "dependent": 2,
#           "dependentGloss": "few"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 3,
#           "dependentGloss": "buffalo"
#         },
#         {
#           "dep": "cop",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 4,
#           "dependentGloss": "were"
#         },
#         {
#           "dep": "case",
#           "governor": 7,
#           "governorGloss": "coconuts",
#           "dependent": 6,
#           "dependentGloss": "under"
#         },
#         {
#           "dep": "nmod:under",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 7,
#           "dependentGloss": "coconuts"
#         },
#         {
#           "dep": "punct",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 8,
#           "dependentGloss": ","
#         },
#         {
#           "dep": "xcomp",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 9,
#           "dependentGloss": "browsing"
#         },
#         {
#           "dep": "det",
#           "governor": 12,
#           "governorGloss": "verges",
#           "dependent": 10,
#           "dependentGloss": "the"
#         },
#         {
#           "dep": "amod",
#           "governor": 12,
#           "governorGloss": "verges",
#           "dependent": 11,
#           "dependentGloss": "parched"
#         },
#         {
#           "dep": "dobj",
#           "governor": 9,
#           "governorGloss": "browsing",
#           "dependent": 12,
#           "dependentGloss": "verges"
#         },
#         {
#           "dep": "punct",
#           "governor": 5,
#           "governorGloss": "tethered",
#           "dependent": 13,
#           "dependentGloss": "."
#         }
#       ],
#       "sentimentValue": "1",
#       "sentiment": "Negative",
#       "sentimentDistribution": [
#         0.13618026964023,
#         0.6506222841901,
#         0.18344397542555,
#         0.02033024179701,
#         0.00942322894711
#       ],
#       "sentimentTree": "(ROOT|sentiment=1|prob=0.651\r\n  (NP|sentiment=2|prob=0.787 (DT|sentiment=2|prob=0.995 A)\r\n    (@NP|sentiment=2|prob=0.863 (JJ|sentiment=2|prob=0.994 few) (NN|sentiment=2|prob=0.631 buffalo)))\r\n  (@S|sentiment=1|prob=0.654\r\n    (VP|sentiment=1|prob=0.612\r\n      (@VP|sentiment=2|prob=0.481\r\n        (@VP|sentiment=2|prob=0.590\r\n          (@VP|sentiment=2|prob=0.825 (VBD|sentiment=2|prob=0.992 were) (ADJP|sentiment=2|prob=0.631 tethered))\r\n          (PP|sentiment=2|prob=0.723 (IN|sentiment=2|prob=0.989 under) (NP|sentiment=2|prob=0.631 coconuts)))\r\n        (,|sentiment=2|prob=0.997 ,))\r\n      (S|sentiment=2|prob=0.575 (VBG|sentiment=2|prob=0.631 browsing)\r\n        (NP|sentiment=2|prob=0.764 (DT|sentiment=2|prob=0.994 the)\r\n          (@NP|sentiment=2|prob=0.663 (JJ|sentiment=2|prob=0.631 parched) (NNS|sentiment=2|prob=0.949 verges)))))\r\n    (.|sentiment=2|prob=0.997 .)))",
#       "tokens": [
#         {
#           "index": 1,
#           "word": "A",
#           "originalText": "A",
#           "characterOffsetBegin": 194,
#           "characterOffsetEnd": 195,
#           "pos": "DT",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 2,
#           "word": "few",
#           "originalText": "few",
#           "characterOffsetBegin": 196,
#           "characterOffsetEnd": 199,
#           "pos": "JJ",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 3,
#           "word": "buffalo",
#           "originalText": "buffalo",
#           "characterOffsetBegin": 200,
#           "characterOffsetEnd": 207,
#           "pos": "NN",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 4,
#           "word": "were",
#           "originalText": "were",
#           "characterOffsetBegin": 208,
#           "characterOffsetEnd": 212,
#           "pos": "VBD",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 5,
#           "word": "tethered",
#           "originalText": "tethered",
#           "characterOffsetBegin": 213,
#           "characterOffsetEnd": 221,
#           "pos": "JJ",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 6,
#           "word": "under",
#           "originalText": "under",
#           "characterOffsetBegin": 222,
#           "characterOffsetEnd": 227,
#           "pos": "IN",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 7,
#           "word": "coconuts",
#           "originalText": "coconuts",
#           "characterOffsetBegin": 228,
#           "characterOffsetEnd": 236,
#           "pos": "NNS",
#           "before": " ",
#           "after": ""
#         },
#         {
#           "index": 8,
#           "word": ",",
#           "originalText": ",",
#           "characterOffsetBegin": 236,
#           "characterOffsetEnd": 237,
#           "pos": ",",
#           "before": "",
#           "after": " "
#         },
#         {
#           "index": 9,
#           "word": "browsing",
#           "originalText": "browsing",
#           "characterOffsetBegin": 238,
#           "characterOffsetEnd": 246,
#           "pos": "VBG",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 10,
#           "word": "the",
#           "originalText": "the",
#           "characterOffsetBegin": 247,
#           "characterOffsetEnd": 250,
#           "pos": "DT",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 11,
#           "word": "parched",
#           "originalText": "parched",
#           "characterOffsetBegin": 251,
#           "characterOffsetEnd": 258,
#           "pos": "JJ",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 12,
#           "word": "verges",
#           "originalText": "verges",
#           "characterOffsetBegin": 259,
#           "characterOffsetEnd": 265,
#           "pos": "NNS",
#           "before": " ",
#           "after": ""
#         },
#         {
#           "index": 13,
#           "word": ".",
#           "originalText": ".",
#           "characterOffsetBegin": 265,
#           "characterOffsetEnd": 266,
#           "pos": ".",
#           "before": "",
#           "after": " "
#         }
#       ]
#     },
#     {
#       "index": 3,
#       "parse": "(ROOT\r\n  (S\r\n    (ADVP (RB Occasionally))\r\n    (NP (DT a) (NN car))\r\n    (VP (VBD went)\r\n      (ADVP (RB past))\r\n      (, ,)\r\n      (S\r\n        (VP (VBG leaving)\r\n          (NP (PRP$ its) (NNS treads))\r\n          (PP (IN in)\r\n            (NP\r\n              (NP (DT the) (NN melting) (NN pitch))\r\n              (PP (IN like)\r\n                (NP\r\n                  (NP (DT the) (NN wake))\r\n                  (PP (IN of)\r\n                    (NP\r\n                      (NP (DT a) (NN ship))\r\n                      (PP (IN at)\r\n                        (NP (NN sea))))))))))))\r\n    (. .)))",
#       "basicDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 4,
#           "dependentGloss": "went"
#         },
#         {
#           "dep": "advmod",
#           "governor": 4,
#           "governorGloss": "went",
#           "dependent": 1,
#           "dependentGloss": "Occasionally"
#         },
#         {
#           "dep": "det",
#           "governor": 3,
#           "governorGloss": "car",
#           "dependent": 2,
#           "dependentGloss": "a"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 4,
#           "governorGloss": "went",
#           "dependent": 3,
#           "dependentGloss": "car"
#         },
#         {
#           "dep": "advmod",
#           "governor": 4,
# ...
#           "governorGloss": "Cristalino",
#           "dependent": 12,
#           "dependentGloss": "around"
#         },
#         {
#           "dep": "compound",
#           "governor": 14,
#           "governorGloss": "Cristalino",
#           "dependent": 13,
#           "dependentGloss": "Rio"
#         },
#         {
#           "dep": "nmod",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 14,
#           "dependentGloss": "Cristalino"
#         },
#         {
#           "dep": "cc",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 15,
#           "dependentGloss": "and"
#         },
#         {
#           "dep": "conj",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 16,
#           "dependentGloss": "planting"
#         },
#         {
#           "dep": "dobj",
#           "governor": 16,
#           "governorGloss": "planting",
#           "dependent": 17,
#           "dependentGloss": "it"
#         },
#         {
#           "dep": "case",
#           "governor": 19,
#           "governorGloss": "coffee",
#           "dependent": 18,
#           "dependentGloss": "with"
#         },
#         {
#           "dep": "nmod",
#           "governor": 16,
#           "governorGloss": "planting",
#           "dependent": 19,
#           "dependentGloss": "coffee"
#         },
#         {
#           "dep": "punct",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 20,
#           "dependentGloss": "."
#         }
#       ],
#       "enhancedDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 4,
#           "dependentGloss": "had"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 2,
#           "governorGloss": "father",
#           "dependent": 1,
#           "dependentGloss": "Her"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 2,
#           "dependentGloss": "father"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 16,
#           "governorGloss": "planting",
#           "dependent": 2,
#           "dependentGloss": "father"
#         },
#         {
#           "dep": "aux",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 3,
#           "dependentGloss": "had"
#         },
#         {
#           "dep": "det",
#           "governor": 6,
#           "governorGloss": "success",
#           "dependent": 5,
#           "dependentGloss": "some"
#         },
#         {
#           "dep": "dobj",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 6,
#           "dependentGloss": "success"
#         },
#         {
#           "dep": "case",
#           "governor": 8,
#           "governorGloss": "buying",
#           "dependent": 7,
#           "dependentGloss": "through"
#         },
#         {
#           "dep": "nmod:through",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 8,
#           "dependentGloss": "buying"
#         },
#         {
#           "dep": "cc",
#           "governor": 8,
#           "governorGloss": "buying",
#           "dependent": 9,
#           "dependentGloss": "and"
#         },
#         {
#           "dep": "compound",
#           "governor": 11,
#           "governorGloss": "land",
#           "dependent": 10,
#           "dependentGloss": "clearing"
#         },
#         {
#           "dep": "nmod:through",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 11,
#           "dependentGloss": "land"
#         },
#         {
#           "dep": "conj:and",
#           "governor": 8,
#           "governorGloss": "buying",
#           "dependent": 11,
#           "dependentGloss": "land"
#         },
#         {
#           "dep": "case",
#           "governor": 14,
#           "governorGloss": "Cristalino",
#           "dependent": 12,
#           "dependentGloss": "around"
#         },
#         {
#           "dep": "compound",
#           "governor": 14,
#           "governorGloss": "Cristalino",
#           "dependent": 13,
#           "dependentGloss": "Rio"
#         },
#         {
#           "dep": "nmod:around",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 14,
#           "dependentGloss": "Cristalino"
#         },
#         {
#           "dep": "cc",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 15,
#           "dependentGloss": "and"
#         },
#         {
#           "dep": "conj:and",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 16,
#           "dependentGloss": "planting"
#         },
#         {
#           "dep": "dobj",
#           "governor": 16,
#           "governorGloss": "planting",
#           "dependent": 17,
#           "dependentGloss": "it"
#         },
#         {
#           "dep": "case",
#           "governor": 19,
#           "governorGloss": "coffee",
#           "dependent": 18,
#           "dependentGloss": "with"
#         },
#         {
#           "dep": "nmod:with",
#           "governor": 16,
#           "governorGloss": "planting",
#           "dependent": 19,
#           "dependentGloss": "coffee"
#         },
#         {
#           "dep": "punct",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 20,
#           "dependentGloss": "."
#         }
#       ],
#       "enhancedPlusPlusDependencies": [
#         {
#           "dep": "ROOT",
#           "governor": 0,
#           "governorGloss": "ROOT",
#           "dependent": 4,
#           "dependentGloss": "had"
#         },
#         {
#           "dep": "nmod:poss",
#           "governor": 2,
#           "governorGloss": "father",
#           "dependent": 1,
#           "dependentGloss": "Her"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 2,
#           "dependentGloss": "father"
#         },
#         {
#           "dep": "nsubj",
#           "governor": 16,
#           "governorGloss": "planting",
#           "dependent": 2,
#           "dependentGloss": "father"
#         },
#         {
#           "dep": "aux",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 3,
#           "dependentGloss": "had"
#         },
#         {
#           "dep": "det",
#           "governor": 6,
#           "governorGloss": "success",
#           "dependent": 5,
#           "dependentGloss": "some"
#         },
#         {
#           "dep": "dobj",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 6,
#           "dependentGloss": "success"
#         },
#         {
#           "dep": "case",
#           "governor": 8,
#           "governorGloss": "buying",
#           "dependent": 7,
#           "dependentGloss": "through"
#         },
#         {
#           "dep": "nmod:through",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 8,
#           "dependentGloss": "buying"
#         },
#         {
#           "dep": "cc",
#           "governor": 8,
#           "governorGloss": "buying",
#           "dependent": 9,
#           "dependentGloss": "and"
#         },
#         {
#           "dep": "compound",
#           "governor": 11,
#           "governorGloss": "land",
#           "dependent": 10,
#           "dependentGloss": "clearing"
#         },
#         {
#           "dep": "nmod:through",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 11,
#           "dependentGloss": "land"
#         },
#         {
#           "dep": "conj:and",
#           "governor": 8,
#           "governorGloss": "buying",
#           "dependent": 11,
#           "dependentGloss": "land"
#         },
#         {
#           "dep": "case",
#           "governor": 14,
#           "governorGloss": "Cristalino",
#           "dependent": 12,
#           "dependentGloss": "around"
#         },
#         {
#           "dep": "compound",
#           "governor": 14,
#           "governorGloss": "Cristalino",
#           "dependent": 13,
#           "dependentGloss": "Rio"
#         },
#         {
#           "dep": "nmod:around",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 14,
#           "dependentGloss": "Cristalino"
#         },
#         {
#           "dep": "cc",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 15,
#           "dependentGloss": "and"
#         },
#         {
#           "dep": "conj:and",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 16,
#           "dependentGloss": "planting"
#         },
#         {
#           "dep": "dobj",
#           "governor": 16,
#           "governorGloss": "planting",
#           "dependent": 17,
#           "dependentGloss": "it"
#         },
#         {
#           "dep": "case",
#           "governor": 19,
#           "governorGloss": "coffee",
#           "dependent": 18,
#           "dependentGloss": "with"
#         },
#         {
#           "dep": "nmod:with",
#           "governor": 16,
#           "governorGloss": "planting",
#           "dependent": 19,
#           "dependentGloss": "coffee"
#         },
#         {
#           "dep": "punct",
#           "governor": 4,
#           "governorGloss": "had",
#           "dependent": 20,
#           "dependentGloss": "."
#         }
#       ],
#       "sentimentValue": "1",
#       "sentiment": "Negative",
#       "sentimentDistribution": [
#         0.12218128206436,
#         0.55032585778161,
#         0.2332492513355,
#         0.06778620149419,
#         0.02645740732434
#       ],
#       "sentimentTree": "(ROOT|sentiment=1|prob=0.550\r\n  (NP|sentiment=2|prob=0.871 (PRP$|sentiment=2|prob=0.988 Her) (NN|sentiment=2|prob=0.991 father))\r\n  (@S|sentiment=1|prob=0.468\r\n    (VP|sentiment=1|prob=0.422\r\n      (@VP|sentiment=2|prob=0.471\r\n        (VP|sentiment=1|prob=0.494 (VBD|sentiment=2|prob=0.997 had)\r\n          (VP|sentiment=1|prob=0.501\r\n            (@VP|sentiment=1|prob=0.559\r\n              (@VP|sentiment=3|prob=0.619 (VBN|sentiment=2|prob=0.997 had)\r\n                (NP|sentiment=3|prob=0.755 (DT|sentiment=2|prob=0.996 some) (NN|sentiment=3|prob=0.922 success)))\r\n              (PP|sentiment=1|prob=0.528 (IN|sentiment=2|prob=0.997 through)\r\n                (NP|sentiment=1|prob=0.398\r\n                  (@NP|sentiment=2|prob=0.590 (NN|sentiment=2|prob=0.798 buying)\r\n                    (CC|sentiment=2|prob=0.996 and))\r\n                  (NP|sentiment=2|prob=0.389 (NN|sentiment=2|prob=0.631 clearing) (NN|sentiment=2|prob=0.948 land)))))\r\n            (PP|sentiment=2|prob=0.667 (IN|sentiment=2|prob=0.997 around)\r\n              (NP|sentiment=2|prob=0.583 (NNP|sentiment=2|prob=0.631 Rio) (NNP|sentiment=2|prob=0.631 Cristalino)))))\r\n        (CC|sentiment=2|prob=0.996 and))\r\n      (VP|sentiment=2|prob=0.437\r\n        (@VP|sentiment=2|prob=0.578 (VBG|sentiment=2|prob=0.631 planting) (NP|sentiment=2|prob=0.993 it))\r\n        (PP|sentiment=2|prob=0.880 (IN|sentiment=2|prob=0.992 with) (NP|sentiment=3|prob=0.803 coffee))))\r\n    (.|sentiment=2|prob=0.997 .)))",
#       "tokens": [
#         {
#           "index": 1,
#           "word": "Her",
#           "originalText": "Her",
#           "characterOffsetBegin": 745,
#           "characterOffsetEnd": 748,
#           "pos": "PRP$",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 2,
#           "word": "father",
#           "originalText": "father",
#           "characterOffsetBegin": 749,
#           "characterOffsetEnd": 755,
#           "pos": "NN",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 3,
#           "word": "had",
#           "originalText": "had",
#           "characterOffsetBegin": 756,
#           "characterOffsetEnd": 759,
#           "pos": "VBD",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 4,
#           "word": "had",
#           "originalText": "had",
#           "characterOffsetBegin": 760,
#           "characterOffsetEnd": 763,
#           "pos": "VBN",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 5,
#           "word": "some",
#           "originalText": "some",
#           "characterOffsetBegin": 764,
#           "characterOffsetEnd": 768,
#           "pos": "DT",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 6,
#           "word": "success",
#           "originalText": "success",
#           "characterOffsetBegin": 769,
#           "characterOffsetEnd": 776,
#           "pos": "NN",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 7,
#           "word": "through",
#           "originalText": "through",
#           "characterOffsetBegin": 777,
#           "characterOffsetEnd": 784,
#           "pos": "IN",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 8,
#           "word": "buying",
#           "originalText": "buying",
#           "characterOffsetBegin": 785,
#           "characterOffsetEnd": 791,
#           "pos": "NN",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 9,
#           "word": "and",
#           "originalText": "and",
#           "characterOffsetBegin": 792,
#           "characterOffsetEnd": 795,
#           "pos": "CC",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 10,
#           "word": "clearing",
#           "originalText": "clearing",
#           "characterOffsetBegin": 796,
#           "characterOffsetEnd": 804,
#           "pos": "NN",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 11,
#           "word": "land",
#           "originalText": "land",
#           "characterOffsetBegin": 805,
#           "characterOffsetEnd": 809,
#           "pos": "NN",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 12,
#           "word": "around",
#           "originalText": "around",
#           "characterOffsetBegin": 810,
#           "characterOffsetEnd": 816,
#           "pos": "IN",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 13,
#           "word": "Rio",
#           "originalText": "Rio",
#           "characterOffsetBegin": 817,
#           "characterOffsetEnd": 820,
#           "pos": "NNP",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 14,
#           "word": "Cristalino",
#           "originalText": "Cristalino",
#           "characterOffsetBegin": 821,
#           "characterOffsetEnd": 831,
#           "pos": "NNP",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 15,
#           "word": "and",
#           "originalText": "and",
#           "characterOffsetBegin": 832,
#           "characterOffsetEnd": 835,
#           "pos": "CC",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 16,
#           "word": "planting",
#           "originalText": "planting",
#           "characterOffsetBegin": 836,
#           "characterOffsetEnd": 844,
#           "pos": "VBG",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 17,
#           "word": "it",
#           "originalText": "it",
#           "characterOffsetBegin": 845,
#           "characterOffsetEnd": 847,
#           "pos": "PRP",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 18,
#           "word": "with",
#           "originalText": "with",
#           "characterOffsetBegin": 848,
#           "characterOffsetEnd": 852,
#           "pos": "IN",
#           "before": " ",
#           "after": " "
#         },
#         {
#           "index": 19,
#           "word": "coffee",
#           "originalText": "coffee",
#           "characterOffsetBegin": 853,
#           "characterOffsetEnd": 859,
#           "pos": "NN",
#           "before": " ",
#           "after": ""
#         },
#         {
#           "index": 20,
#           "word": ".",
#           "originalText": ".",
#           "characterOffsetBegin": 859,
#           "characterOffsetEnd": 860,
#           "pos": ".",
#           "before": "",
#           "after": ""
#         }
#       ]
#     }
#   ]
# }
